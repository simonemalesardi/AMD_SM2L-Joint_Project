# %%
import numpy as np
import pandas as pd

from pyspark.sql.types import *
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, to_timestamp, sum as _sum, count, monotonically_increasing_id

# %% [markdown]
# # Pattern reading
# Patters are read from the txt file and the result is stored in a csv file

# %%
with open('datasets/HI-Small_Patterns.txt') as f:
    small_patterns = f.readlines()
    
laundering = []
laundering_with_categories = []
for row in small_patterns:
    if 'BEGIN LAUNDERING ATTEMPT' in row:
        row = row.replace('\n','')
        laundering_with_categories.append(row)
        laund = row.split(':')[0]
        laundering.append(laund.split('- ')[1])
        
print(set(laundering))

dict_laundering = {}
for laund in laundering: 
    dict_laundering[laund] = {}
    
array_patterns = []
for key in dict_laundering.keys(): #filtro per il nome della frode
    count = 0
    insert = False
    type_laundering = None
    for row in small_patterns:
        if ('BEGIN LAUNDERING ATTEMPT - '+key) in row: #filtro per tutte le frodi di quel tipo
            insert = True
            type = row.split(':  ')
            if len(type) == 2: #considero la categoria (e.g. Max 13-degree Fan-In)
                type_laundering = type[1].replace('\n', '')

            dict_laundering[key][count] = []
        elif ('END LAUNDERING ATTEMPT - '+key) in row:
            count += 1
            type_laundering = None
            insert = False
        elif insert: 
            array_row = row.replace('\n','').split(',')
            patt = [count, key]
            for el in array_row: 
                patt.append(el)

            if type_laundering == None:       
                patt.append(None)     
                dict_laundering[key][count].append(array_row)
            else: 
                patt.append(type_laundering)
                dict_laundering[key][count].append(array_row)
            
            array_patterns.append(patt)
            
columns = ['id','type','timestamp','from_bank','from_account','to_bank','to_account','amount_received','receiving_currency','amount_paid','payment_currency','payment_format','is_laundering','category']
pd.DataFrame(array_patterns, columns=columns).to_csv('datasets/HI-Small_Patterns.csv',index=False)
# Out:
# {'SCATTER-GATHER', 'CYCLE', 'BIPARTITE', 'RANDOM', 'STACK', 'GATHER-SCATTER', 'FAN-IN', 'FAN-OUT'}

# %% [markdown]
# The features calculated in the previous code are:
# - id
# - type
# - category
#
# Transactions with these 3 identical features mean that they belong to the same type of illecit transaction

# %% [markdown]
# # Pattern understanding

# %%
spark = SparkSession.builder \
    .appName("AMD-SM2L Joint Project") \
    .config("spark.driver.memory", "3g") \
    .config("spark.executor.memory", "4g") \
    .config("spark.sql.execution.arrow.pyspark.enabled", "true") \
    .config("spark.sql.execution.arrow.enabled", "true") \
    .master("local[*]") \
    .getOrCreate()

spark.sparkContext.setLogLevel("OFF")
dataframe = spark.read.parquet("datasets/1_cleaned_HI-Small.parquet", header=True)
dataframe = dataframe.withColumn('id', monotonically_increasing_id())

ds = pd.read_csv('datasets/HI-Small_Patterns.csv')

# %%
reduced_ds = ds[['timestamp','from_bank','from_account','to_bank','to_account','amount_received','receiving_currency','amount_paid','payment_currency','payment_format']]
pattern_len, df_len = len(reduced_ds.drop_duplicates()), dataframe.filter('is_laundering==1').count()
print("Laundering in pattern file: {}\nLaundering in the dataframe: {}".format(pattern_len, df_len))
print("Missing launderings:",df_len-pattern_len)
# Out:
# [Stage 1:>                                                          (0 + 8) / 9]
# Laundering in pattern file: 3209
# Laundering in the dataframe: 5177
# Missing launderings: 1968

# %% [markdown]
# Not all laundering transactions in the dataframe downloaded from Kaggle were reported in the pattern txt file

# %% [markdown]
# Types of Laundering Patterns
#
# <img src="images/patterns.png" style="width: 600px">

# %%
set(ds.type)
# Out:
# {'BIPARTITE',
#  'CYCLE',
#  'FAN-IN',
#  'FAN-OUT',
#  'GATHER-SCATTER',
#  'RANDOM',
#  'SCATTER-GATHER',
#  'STACK'}

# %%
def filter_dataframe(receiving_currency, payment_currency, payment_format="ACH", from_bank=None, from_account=None, to_bank=None, to_account=None):
    if to_bank == None and to_account == None:
        dataframe.filter('from_bank=={} and \
                        from_account=="{}" and \
                        receiving_currency=="{}" and \
                        payment_currency=="{}" and \
                        payment_format=="{}"'.format(from_bank, from_account, receiving_currency, payment_currency, payment_format)).sort('timestamp').show()
    elif from_bank == None and from_account == None:
        dataframe.filter('to_bank=={} and \
                        to_account=="{}" and \
                        receiving_currency=="{}" and \
                        payment_currency=="{}" and \
                        payment_format=="{}"'.format(to_bank, to_account, receiving_currency, payment_currency, payment_format)).sort('timestamp').show()
    else:
        dataframe.filter('from_bank=={} and \
                        from_account=="{}" and \
                        to_bank=={} and \
                        to_account=="{}" and \
                        receiving_currency=="{}" and \
                        payment_currency=="{}" and \
                        payment_format=="{}"'.format(from_bank, from_account, to_bank, to_account, receiving_currency, payment_currency, payment_format)).sort('timestamp').show()

# %% [markdown]
# # FAN-OUT (fig. a)

# %%
fan_out = ds[ds.type=='FAN-OUT']

# %% [markdown]
# ### More than 1-degree

# %% [markdown]
# ##### Example 1

# %%
fan_out0 = fan_out[fan_out.id==10]
fan_out0
# Out:
#     id     type         timestamp  from_bank from_account  to_bank to_account  \
# 87  10  FAN-OUT  2022/09/02 06:37     150240    812D22980    48309  811C599A0
# 88  10  FAN-OUT  2022/09/02 09:09     150240    812D22980      222  811B83280
#
#     amount_received receiving_currency  amount_paid payment_currency  \
# 87         60056.52        Saudi Riyal     60056.52      Saudi Riyal
# 88         59890.28        Saudi Riyal     59890.28      Saudi Riyal
#
#    payment_format  is_laundering              category
# 87            ACH              1  Max 2-degree Fan-Out
# 88            ACH              1  Max 2-degree Fan-Out

# %% [markdown]
# All transactions are:
# - sent from 812D22980 to bank 150240
# - receiving_currency = payment_currency = Saudi Riyal
# - payment_format = ACH
# Let's try to see how many launderings there are in the dataset that reflect these characteristics

# %%
filter_dataframe("Saudi Riyal","Saudi Riyal", from_bank=150240, from_account="812D22980")
# Out:
# [Stage 19:>                                                         (0 + 8) / 8]
# +-------------------+---------+------------+-------+----------+---------------+------------------+-----------+----------------+--------------+-------------+-----------+
# |          timestamp|from_bank|from_account|to_bank|to_account|amount_received|receiving_currency|amount_paid|payment_currency|payment_format|is_laundering|         id|
# +-------------------+---------+------------+-------+----------+---------------+------------------+-----------+----------------+--------------+-------------+-----------+
# |2022-09-01 06:47:00|   150240|   812D22980|  48309| 811C599A0|       27247.23|       Saudi Riyal|   27247.23|     Saudi Riyal|           ACH|            1|51539675261|
# |2022-09-01 19:27:00|   150240|   812D22980|  48309| 811C599A0|        5971.98|       Saudi Riyal|    5971.98|     Saudi Riyal|           ACH|            1|      40064|
# |2022-09-02 06:37:00|   150240|   812D22980|  48309| 811C599A0|       60056.52|       Saudi Riyal|   60056.52|     Saudi Riyal|           ACH|            1|42949841138|
# |2022-09-02 09:09:00|   150240|   812D22980|    222| 811B83280|       59890.28|       Saudi Riyal|   59890.28|     Saudi Riyal|           ACH|            1|42949841139|
# |2022-09-03 00:47:00|   150240|   812D22980|    119| 811C597B0|       14052.22|       Saudi Riyal|   14052.22|     Saudi Riyal|           ACH|            1|60129777825|
# |2022-09-03 16:22:00|   150240|   812D22980|    222| 811B83280|       45292.05|       Saudi Riyal|   45292.05|     Saudi Riyal|           ACH|            1|25770040324|
# |2022-09-04 00:35:00|   150240|   812D22980|    119| 811C597B0|       28482.42|       Saudi Riyal|   28482.42|     Saudi Riyal|           ACH|            1| 8590193882|
# |2022-09-04 04:53:00|   150240|   812D22980|    119| 811C597B0|       64974.79|       Saudi Riyal|   64974.79|     Saudi Riyal|           ACH|            1|51539740558|
# |2022-09-04 18:56:00|   150240|   812D22980|    222| 811B83280|       53921.32|       Saudi Riyal|   53921.32|     Saudi Riyal|           ACH|            1|34360017842|
# |2022-09-04 19:29:00|   150240|   812D22980|  48309| 811C599A0|        50550.9|       Saudi Riyal|    50550.9|     Saudi Riyal|           ACH|            1|17180144295|
# |2022-09-04 21:37:00|   150240|   812D22980| 150240| 812D22980|       71726.48|       Saudi Riyal|   71726.48|     Saudi Riyal|           ACH|            1| 8590182725|
# |2022-09-05 05:54:00|   150240|   812D22980|  48309| 811C599A0|         655.64|       Saudi Riyal|     655.64|     Saudi Riyal|           ACH|            1| 8590139546|
# |2022-09-05 12:57:00|   150240|   812D22980|    222| 811B83280|       48318.33|       Saudi Riyal|   48318.33|     Saudi Riyal|           ACH|            1|51539855927|
# |2022-09-05 23:10:00|   150240|   812D22980|  48309| 811C599A0|       34685.98|       Saudi Riyal|   34685.98|     Saudi Riyal|           ACH|            1|25770148940|
# |2022-09-06 15:42:00|   150240|   812D22980|    119| 811C597B0|       10005.08|       Saudi Riyal|   10005.08|     Saudi Riyal|           ACH|            1|51539855928|
# |2022-09-07 10:23:00|   150240|   812D22980|    119| 811C597B0|       64806.02|       Saudi Riyal|   64806.02|     Saudi Riyal|           ACH|            1|34360170755|
# |2022-09-07 13:11:00|   150240|   812D22980|    119| 811C597B0|       28525.51|       Saudi Riyal|   28525.51|     Saudi Riyal|           ACH|            1|51539959813|
# |2022-09-07 23:48:00|   150240|   812D22980|  48309| 811C599A0|       55801.94|       Saudi Riyal|   55801.94|     Saudi Riyal|           ACH|            1|42950138353|
# |2022-09-08 17:08:00|   150240|   812D22980|  48309| 811C599A0|       69596.64|       Saudi Riyal|   69596.64|     Saudi Riyal|           ACH|            1|42950062619|
# |2022-09-08 23:38:00|   150240|   812D22980|    222| 811B83280|       53315.63|       Saudi Riyal|   53315.63|     Saudi Riyal|           ACH|            1|25770331162|
# +-------------------+---------+------------+-------+----------+---------------+------------------+-----------+----------------+--------------+-------------+-----------+
# only showing top 20 rows

# %% [markdown]
# All transactions with those characteristics are laundering

# %% [markdown]
# ##### Example 2

# %%
fan_out1 = fan_out[fan_out.id==0]
display(fan_out1)
filter_dataframe("US Dollar","US Dollar", from_bank=21174, from_account="800737690")
# Out:
#     id     type         timestamp  from_bank from_account  to_bank to_account  \
# 0    0  FAN-OUT  2022/09/01 00:06      21174    800737690       12  80011F990
# 1    0  FAN-OUT  2022/09/01 04:33      21174    800737690       20  80020C5B0
# 2    0  FAN-OUT  2022/09/01 09:14      21174    800737690       20  80006A5E0
# 3    0  FAN-OUT  2022/09/01 09:56      21174    800737690      220  8007A5B70
# 4    0  FAN-OUT  2022/09/01 11:28      21174    800737690     1244  80093C0D0
# 5    0  FAN-OUT  2022/09/01 13:13      21174    800737690      513  80078E200
# 6    0  FAN-OUT  2022/09/01 14:11      21174    800737690       20  80066B990
# 7    0  FAN-OUT  2022/09/02 15:40      21174    800737690      410  8002CC310
# 8    0  FAN-OUT  2022/09/02 21:23      21174    800737690     1292  8004030A0
# 9    0  FAN-OUT  2022/09/02 23:10      21174    800737690     1601  800578800
# 10   0  FAN-OUT  2022/09/03 09:29      21174    800737690        1  800AAF0B0
# 11   0  FAN-OUT  2022/09/03 14:22      21174    800737690     1420  8006FB970
# 12   0  FAN-OUT  2022/09/04 07:35      21174    800737690       10  800449990
# 13   0  FAN-OUT  2022/09/04 09:10      21174    800737690    11852  800AEBA90
# 14   0  FAN-OUT  2022/09/04 12:03      21174    800737690       10  800692550
# 15   0  FAN-OUT  2022/09/04 15:48      21174    800737690    11056  8007486D0
#
#     amount_received receiving_currency  amount_paid payment_currency  \
# 0           2848.96               Euro      2848.96             Euro
# 1           8630.40               Euro      8630.40             Euro
# 2          35642.49               Yuan     35642.49             Yuan
# 3        5738987.96          US Dollar   5738987.96        US Dollar
# 4           7254.53          US Dollar      7254.53        US Dollar
# 5           6990.87          US Dollar      6990.87        US Dollar
# 6          12536.92               Euro     12536.92             Euro
# 7           3511.82               Euro      3511.82             Euro
# 8          16135.09          US Dollar     16135.09        US Dollar
# 9          12183.28          US Dollar     12183.28        US Dollar
# 10         15197.45          US Dollar     15197.45        US Dollar
# 11          4717.76          US Dollar      4717.76        US Dollar
# 12         19332.59          US Dollar     19332.59        US Dollar
# 13           300.93               Euro       300.93             Euro
# 14          2724.99          US Dollar      2724.99        US Dollar
# 15         15224.53               Euro     15224.53             Euro
#
#    payment_format  is_laundering               category
# 0             ACH              1  Max 16-degree Fan-Out
# 1             ACH              1  Max 16-degree Fan-Out
# 2             ACH              1  Max 16-degree Fan-Out
# 3             ACH              1  Max 16-degree Fan-Out
# 4             ACH              1  Max 16-degree Fan-Out
# 5             ACH              1  Max 16-degree Fan-Out
# 6             ACH              1  Max 16-degree Fan-Out
# 7             ACH              1  Max 16-degree Fan-Out
# 8             ACH              1  Max 16-degree Fan-Out
# 9             ACH              1  Max 16-degree Fan-Out
# 10            ACH              1  Max 16-degree Fan-Out
# 11            ACH              1  Max 16-degree Fan-Out
# 12            ACH              1  Max 16-degree Fan-Out
# 13            ACH              1  Max 16-degree Fan-Out
# 14            ACH              1  Max 16-degree Fan-Out
# 15            ACH              1  Max 16-degree Fan-Out
# +-------------------+---------+------------+-------+----------+---------------+------------------+-----------+----------------+--------------+-------------+-----------+
# |          timestamp|from_bank|from_account|to_bank|to_account|amount_received|receiving_currency|amount_paid|payment_currency|payment_format|is_laundering|         id|
# +-------------------+---------+------------+-------+----------+---------------+------------------+-----------+----------------+--------------+-------------+-----------+
# |2022-09-01 09:46:00|   225734|   8095AF170|   1362| 802783AA0|       16737.85|         US Dollar|   16737.85|       US Dollar|           ACH|            1|34359818776|
# |2022-09-01 11:11:00|   225734|   8095AF170|  28694| 804ED8800|       17321.44|         US Dollar|   17321.44|       US Dollar|           ACH|            1|25769884739|
# |2022-09-01 17:54:00|   225734|   8095AF170|  11904| 800E9BC40|        4382.74|         US Dollar|    4382.74|       US Dollar|           ACH|            1|17179949996|
# |2022-09-02 15:47:00|   225734|   8095AF170|   2053| 80F2FC160|       12461.78|         US Dollar|   12461.78|       US Dollar|           ACH|            1|42949753468|
# |2022-09-03 15:22:00|   225734|   8095AF170| 133826| 80FCC36A0|       19595.51|         US Dollar|   19595.51|       US Dollar|           ACH|            1|34359818779|
# |2022-09-03 17:33:00|   225734|   8095AF170|   9129| 80623F410|        6442.75|         US Dollar|    6442.75|       US Dollar|           ACH|            1|25769884742|
# +-------------------+---------+------------+-------+----------+---------------+------------------+-----------+----------------+--------------+-------------+-----------+

# %%
dataframe.filter('from_bank==20 and from_account=="8001C97D0"').show()
# Out:
# +-------------------+---------+------------+-------+----------+---------------+------------------+-----------+----------------+--------------+-------------+----------+
# |          timestamp|from_bank|from_account|to_bank|to_account|amount_received|receiving_currency|amount_paid|payment_currency|payment_format|is_laundering|        id|
# +-------------------+---------+------------+-------+----------+---------------+------------------+-----------+----------------+--------------+-------------+----------+
# |2022-09-01 00:21:00|       20|   8001C97D0| 122094| 8088E2210|        6331.16|              Euro|    6331.16|            Euro|        Cheque|            0|     20249|
# |2022-09-01 00:25:00|       20|   8001C97D0| 122094| 8088E2210|        3044.58|              Euro|    3044.58|            Euro|   Credit Card|            0|     20250|
# |2022-09-01 00:26:00|       20|   8001C97D0| 122094| 8088E2210|         517.35|              Euro|     517.35|            Euro|          Wire|            0|     20251|
# |2022-09-01 06:14:00|       20|   8001C97D0|  23525| 8018FF9E0|        4160.07|              Euro|    4160.07|            Euro|        Cheque|            0|     64912|
# |2022-09-01 12:00:00|       20|   8001C97D0|   1547| 800991790|        1273.28|              Euro|    1273.28|            Euro|   Credit Card|            0|     90179|
# |2022-09-01 17:23:00|       20|   8001C97D0|     22| 800201C60|          12.88|              Euro|      12.88|            Euro|        Cheque|            0|    111433|
# |2022-09-01 17:16:00|       20|   8001C97D0|     22| 800201C60|          46.23|              Euro|      46.23|            Euro|          Cash|            0|    111434|
# |2022-09-03 04:12:00|       20|   8001C97D0|     11| 8002464E0|       18073.47|              Euro|   18073.47|            Euro|   Credit Card|            0|    240825|
# |2022-09-05 20:49:00|       20|   8001C97D0|     11| 8002464E0|      444255.58|              Euro|  444255.58|            Euro|        Cheque|            0|    339465|
# |2022-09-06 15:05:00|       20|   8001C97D0|  23525| 8018FF9E0|       14301.87|              Euro|   14301.87|            Euro|          Cash|            0|    386349|
# |2022-09-07 04:19:00|       20|   8001C97D0|   1547| 800991790|         119.47|              Euro|     119.47|            Euro|        Cheque|            0|    419953|
# |2022-09-08 01:21:00|       20|   8001C97D0|  23525| 8018FF9E0|        4160.07|              Euro|    4160.07|            Euro|        Cheque|            0|    473349|
# |2022-09-08 05:20:00|       20|   8001C97D0|     11| 8002464E0|      444255.58|              Euro|  444255.58|            Euro|        Cheque|            0|    483101|
# |2022-09-09 01:18:00|       20|   8001C97D0|   1547| 800991790|        1273.28|              Euro|    1273.28|            Euro|   Credit Card|            0|    534715|
# |2022-09-14 04:40:00|       20|   8001C97D0|     23| 800240940|        9460.73|              Euro|    9460.73|            Euro|           ACH|            1|    628468|
# |2022-09-01 00:15:00|       20|   8001C97D0|    410| 800C774E0|         523.77|              Euro|     523.77|            Euro|          Cash|            0|8589950438|
# |2022-09-02 03:01:00|       20|   8001C97D0|     22| 800201C60|          46.23|              Euro|      46.23|            Euro|          Cash|            0|8590088443|
# |2022-09-02 04:43:00|       20|   8001C97D0|  23525| 8018FF9E0|        4160.07|              Euro|    4160.07|            Euro|        Cheque|            0|8590094318|
# |2022-09-03 04:03:00|       20|   8001C97D0|     11| 8002464E0|      444255.58|              Euro|  444255.58|            Euro|        Cheque|            0|8590174357|
# |2022-09-05 13:05:00|       20|   8001C97D0|     22| 80051AD00|        32446.7|              Euro|    32446.7|            Euro|          Wire|            0|8590254579|
# +-------------------+---------+------------+-------+----------+---------------+------------------+-----------+----------------+--------------+-------------+----------+
# only showing top 20 rows

# %% [markdown]
# ### 1-degree

# %%
fan_out1degree = fan_out[fan_out.category=="Max 1-degree Fan-Out"]
fan_out1degree
# Out:
#      id     type         timestamp  from_bank from_account  to_bank  \
# 73    7  FAN-OUT  2022/09/02 03:04      15231    80266F880    23691
# 113  15  FAN-OUT  2022/09/03 22:15      15231    80266F880    23691
# 132  19  FAN-OUT  2022/09/04 15:30      15231    80266F880    23691
# 154  24  FAN-OUT  2022/09/06 10:04      49365    812A09D40      119
# 204  29  FAN-OUT  2022/09/07 00:21        119    812A09CF0    49365
# 205  30  FAN-OUT  2022/09/07 00:53      23691    8021353D0    15231
# 280  40  FAN-OUT  2022/09/09 15:30     249176    812A70ED0    49508
# 295  43  FAN-OUT  2022/09/09 18:42      50202    812D129C0      222
#
#     to_account  amount_received receiving_currency  amount_paid  \
# 73   8021353D0         15536.84               Euro     15536.84
# 113  8021353D0         12592.29               Euro     12592.29
# 132  8021353D0          8092.93               Euro      8092.93
# 154  812A09CF0         32736.73        Saudi Riyal     32736.73
# 204  812A09D40         12260.49        Saudi Riyal     12260.49
# 205  80266F880          6149.56               Euro      6149.56
# 280  812A70E80         17579.07        Saudi Riyal     17579.07
# 295  812D127D0         70077.51        Saudi Riyal     70077.51
#
#     payment_currency payment_format  is_laundering              category
# 73              Euro            ACH              1  Max 1-degree Fan-Out
# 113             Euro            ACH              1  Max 1-degree Fan-Out
# 132             Euro            ACH              1  Max 1-degree Fan-Out
# 154      Saudi Riyal            ACH              1  Max 1-degree Fan-Out
# 204      Saudi Riyal            ACH              1  Max 1-degree Fan-Out
# 205             Euro            ACH              1  Max 1-degree Fan-Out
# 280      Saudi Riyal            ACH              1  Max 1-degree Fan-Out
# 295      Saudi Riyal            ACH              1  Max 1-degree Fan-Out

# %% [markdown]
# Taking into consideration for example the transaction with id 24 with Max 1-degree, looking in the complete dataset we find that all the transactions having the same characteristics are laundering.

# %%
display(fan_out1degree[fan_out1degree.id==24])
filter_dataframe(receiving_currency="Saudi Riyal", payment_currency="Saudi Riyal", from_bank=49365, from_account="812A09D40", to_bank=119, to_account="812A09CF0")

# %%
display(fan_out1degree[fan_out1degree.id==29])
filter_dataframe(receiving_currency="Saudi Riyal", payment_currency="Saudi Riyal", from_bank=119, from_account="812A09CF0", to_bank=49365, to_account="812A09D40")

# %% [markdown]
# ### Final understanding

# %%
features_fan_out = ['timestamp','from_account','from_bank','category','payment_format']
fan_outDF = spark.createDataFrame(fan_out)
fan_outDF = fan_outDF.withColumn("timestamp", to_timestamp(col("timestamp"), "yyyy/MM/dd HH:mm"))
fan_outDF = fan_outDF.select(features_fan_out)\
    .groupBy('from_account','from_bank','category','payment_format')\
        .agg(count('*').alias('count'), 
             min('timestamp').alias('min_ts'),
             max('timestamp').alias('max_ts'))\
            .select('from_account','from_bank','category','count','payment_format','min_ts','max_ts')

fan_outDF.withColumn('timestamp_range', datediff(col('max_ts'), col('min_ts'))).orderBy('category').show(truncate=False)
# Out:
# +------------+---------+---------------------+-----+--------------+-------------------+-------------------+---------------+
# |from_account|from_bank|category             |count|payment_format|min_ts             |max_ts             |timestamp_range|
# +------------+---------+---------------------+-----+--------------+-------------------+-------------------+---------------+
# |80266F880   |15231    |Max 1-degree Fan-Out |3    |ACH           |2022-09-02 03:04:00|2022-09-04 15:30:00|2              |
# |812A09D40   |49365    |Max 1-degree Fan-Out |1    |ACH           |2022-09-06 10:04:00|2022-09-06 10:04:00|0              |
# |812A09CF0   |119      |Max 1-degree Fan-Out |1    |ACH           |2022-09-07 00:21:00|2022-09-07 00:21:00|0              |
# |8021353D0   |23691    |Max 1-degree Fan-Out |1    |ACH           |2022-09-07 00:53:00|2022-09-07 00:53:00|0              |
# |812A70ED0   |249176   |Max 1-degree Fan-Out |1    |ACH           |2022-09-09 15:30:00|2022-09-09 15:30:00|0              |
# |812D129C0   |50202    |Max 1-degree Fan-Out |1    |ACH           |2022-09-09 18:42:00|2022-09-09 18:42:00|0              |
# |8001BB380   |10       |Max 10-degree Fan-Out|10   |ACH           |2022-09-01 17:48:00|2022-09-04 18:07:00|3              |
# |8001C97D0   |20       |Max 10-degree Fan-Out|10   |ACH           |2022-09-10 15:36:00|2022-09-14 15:19:00|4              |
# |80338EC60   |11107    |Max 11-degree Fan-Out|11   |ACH           |2022-09-03 05:59:00|2022-09-07 05:06:00|4              |
# |802873390   |25075    |Max 11-degree Fan-Out|11   |ACH           |2022-09-09 18:12:00|2022-09-12 18:14:00|3              |
# |80F1AF380   |116      |Max 12-degree Fan-Out|12   |ACH           |2022-09-01 01:34:00|2022-09-04 18:23:00|3              |
# |803B24460   |15       |Max 12-degree Fan-Out|12   |ACH           |2022-09-01 21:59:00|2022-09-04 13:24:00|3              |
# |811A4DBD0   |223      |Max 12-degree Fan-Out|12   |ACH           |2022-09-07 20:02:00|2022-09-11 18:15:00|4              |
# |8095AF170   |225734   |Max 13-degree Fan-Out|13   |ACH           |2022-09-01 09:46:00|2022-09-05 06:04:00|4              |
# |80F962B10   |4403     |Max 13-degree Fan-Out|13   |ACH           |2022-09-10 14:38:00|2022-09-14 13:47:00|4              |
# |8000E1590   |121      |Max 13-degree Fan-Out|13   |ACH           |2022-09-06 19:16:00|2022-09-10 10:40:00|4              |
# |8045F4500   |11128    |Max 13-degree Fan-Out|13   |ACH           |2022-09-07 16:17:00|2022-09-11 14:49:00|4              |
# |808D6F2D0   |21611    |Max 14-degree Fan-Out|14   |ACH           |2022-09-07 18:38:00|2022-09-11 09:42:00|4              |
# |80ED002D0   |231212   |Max 15-degree Fan-Out|15   |ACH           |2022-09-09 18:31:00|2022-09-12 17:26:00|3              |
# |809BFD6B0   |210431   |Max 16-degree Fan-Out|16   |ACH           |2022-09-06 19:15:00|2022-09-10 11:51:00|4              |
# +------------+---------+---------------------+-----+--------------+-------------------+-------------------+---------------+
# only showing top 20 rows

# %% [markdown]
# We can see that the difference between the minimum and maximum timestamp is 4 days.

# %% [markdown]
# #### Particular case

# %% [markdown]
# How is it possibile that a Max 1-degree Fan-Out has 3 in count field?

# %%
fan_out[(fan_out.from_account=="80266F880") & (fan_out.from_bank==15231)]
# Out:
#      id     type         timestamp  from_bank from_account  to_bank  \
# 73    7  FAN-OUT  2022/09/02 03:04      15231    80266F880    23691
# 113  15  FAN-OUT  2022/09/03 22:15      15231    80266F880    23691
# 132  19  FAN-OUT  2022/09/04 15:30      15231    80266F880    23691
#
#     to_account  amount_received receiving_currency  amount_paid  \
# 73   8021353D0         15536.84               Euro     15536.84
# 113  8021353D0         12592.29               Euro     12592.29
# 132  8021353D0          8092.93               Euro      8092.93
#
#     payment_currency payment_format  is_laundering              category
# 73              Euro            ACH              1  Max 1-degree Fan-Out
# 113             Euro            ACH              1  Max 1-degree Fan-Out
# 132             Euro            ACH              1  Max 1-degree Fan-Out

# %% [markdown]
# All of the transactions above are directed to the same account with same currencies. Maybe similar transactions can't be considered the same fan-out (transactions having same to_bank and to_account)
#
# How many cases like this are there in the dataset?

# %%
fan_outDF2 = spark.createDataFrame(fan_out)
fan_outDF2.groupBy('from_bank','from_account','to_bank','to_account', 'receiving_currency','payment_currency').count().filter('count>1').show()
# Out:
# +---------+------------+-------+----------+------------------+----------------+-----+
# |from_bank|from_account|to_bank|to_account|receiving_currency|payment_currency|count|
# +---------+------------+-------+----------+------------------+----------------+-----+
# |    15231|   80266F880|  23691| 8021353D0|              Euro|            Euro|    3|
# |   150240|   812D22980|    222| 811B83280|       Saudi Riyal|     Saudi Riyal|    3|
# |   150240|   812D22980|  48309| 811C599A0|       Saudi Riyal|     Saudi Riyal|    2|
# |   148350|   812D0C3C0| 148350| 811FFF630|       Saudi Riyal|     Saudi Riyal|    2|
# |   148350|   812D0C3C0|  50528| 812D0C600|       Saudi Riyal|     Saudi Riyal|    2|
# |   150240|   812D22980|    119| 811C597B0|       Saudi Riyal|     Saudi Riyal|    2|
# +---------+------------+-------+----------+------------------+----------------+-----+

# %% [markdown]
# For example the transactions above have similar values

# %%
fan_out[(fan_out.from_bank==150240) & (fan_out.from_account=="812D22980") & (fan_out.to_account=="811B83280")]
# Out:
#      id     type         timestamp  from_bank from_account  to_bank  \
# 88   10  FAN-OUT  2022/09/02 09:09     150240    812D22980      222
# 213  32  FAN-OUT  2022/09/10 00:18     150240    812D22980      222
# 282  41  FAN-OUT  2022/09/10 07:41     150240    812D22980      222
#
#     to_account  amount_received receiving_currency  amount_paid  \
# 88   811B83280         59890.28        Saudi Riyal     59890.28
# 213  811B83280          6046.83        Saudi Riyal      6046.83
# 282  811B83280         28341.71        Saudi Riyal     28341.71
#
#     payment_currency payment_format  is_laundering              category
# 88       Saudi Riyal            ACH              1  Max 2-degree Fan-Out
# 213      Saudi Riyal            ACH              1  Max 2-degree Fan-Out
# 282      Saudi Riyal            ACH              1  Max 3-degree Fan-Out

# %% [markdown]
# The two transactions occurred in "2022/09/10 00:18" belong to two different degree category.

# %%
display(fan_out[(fan_out.receiving_currency=="Saudi Riyal") & (fan_out.payment_format=="ACH") & (fan_out.category=="Max 3-degree Fan-Out")])
fan_out[fan_out.id==32]
# Out:
#      id     type         timestamp  from_bank from_account  to_bank  \
# 281  41  FAN-OUT  2022/09/09 15:59     150240    812D22980    48309
# 282  41  FAN-OUT  2022/09/10 07:41     150240    812D22980      222
# 283  41  FAN-OUT  2022/09/11 18:02     150240    812D22980      119
#
#     to_account  amount_received receiving_currency  amount_paid  \
# 281  811C599A0         74116.00        Saudi Riyal     74116.00
# 282  811B83280         28341.71        Saudi Riyal     28341.71
# 283  811C597B0         27043.63        Saudi Riyal     27043.63
#
#     payment_currency payment_format  is_laundering              category
# 281      Saudi Riyal            ACH              1  Max 3-degree Fan-Out
# 282      Saudi Riyal            ACH              1  Max 3-degree Fan-Out
# 283      Saudi Riyal            ACH              1  Max 3-degree Fan-Out
#      id     type         timestamp  from_bank from_account  to_bank  \
# 212  32  FAN-OUT  2022/09/07 10:23     150240    812D22980      119
# 213  32  FAN-OUT  2022/09/10 00:18     150240    812D22980      222
#
#     to_account  amount_received receiving_currency  amount_paid  \
# 212  811C597B0         64806.02        Saudi Riyal     64806.02
# 213  811B83280          6046.83        Saudi Riyal      6046.83
#
#     payment_currency payment_format  is_laundering              category
# 212      Saudi Riyal            ACH              1  Max 2-degree Fan-Out
# 213      Saudi Riyal            ACH              1  Max 2-degree Fan-Out

# %% [markdown]
# In a single fan-out pattern, are curriencies all different?

# %%
fan_outDF = spark.createDataFrame(fan_out)

fan_outDF.select('id','receiving_currency')\
    .groupBy('id','receiving_currency').count()\
    .select('id','receiving_currency')\
    .groupBy('id').count().filter('count<=1').show()
# Out:
# +---+-----+
# | id|count|
# +---+-----+
# | 29|    1|
# | 30|    1|
# |  9|    1|
# | 11|    1|
# | 32|    1|
# | 40|    1|
# | 43|    1|
# | 35|    1|
# |  7|    1|
# | 15|    1|
# | 19|    1|
# | 10|    1|
# | 24|    1|
# | 13|    1|
# | 41|    1|
# +---+-----+

# %%
fan_out[fan_out.id==32]
# Out:
#      id     type         timestamp  from_bank from_account  to_bank  \
# 212  32  FAN-OUT  2022/09/07 10:23     150240    812D22980      119
# 213  32  FAN-OUT  2022/09/10 00:18     150240    812D22980      222
#
#     to_account  amount_received receiving_currency  amount_paid  \
# 212  811C597B0         64806.02        Saudi Riyal     64806.02
# 213  811B83280          6046.83        Saudi Riyal      6046.83
#
#     payment_currency payment_format  is_laundering              category
# 212      Saudi Riyal            ACH              1  Max 2-degree Fan-Out
# 213      Saudi Riyal            ACH              1  Max 2-degree Fan-Out

# %%
fan_out[fan_out.id==1]
# Out:
#     id     type         timestamp  from_bank from_account  to_bank to_account  \
# 16   1  FAN-OUT  2022/09/01 01:34        116    80F1AF380   127593  80A817660
# 17   1  FAN-OUT  2022/09/01 05:44        116    80F1AF380    13145  80D210C20
# 18   1  FAN-OUT  2022/09/01 19:38        116    80F1AF380     9679  809ACB660
# 19   1  FAN-OUT  2022/09/02 05:02        116    80F1AF380     1655  811F9C580
# 20   1  FAN-OUT  2022/09/02 16:17        116    80F1AF380   222819  808CE0050
# 21   1  FAN-OUT  2022/09/02 17:29        116    80F1AF380    21387  803158350
# 22   1  FAN-OUT  2022/09/02 19:56        116    80F1AF380     7042  810C0C4D0
# 23   1  FAN-OUT  2022/09/03 06:57        116    80F1AF380   243614  8113C5790
# 24   1  FAN-OUT  2022/09/03 18:53        116    80F1AF380     1124  805F9C820
# 25   1  FAN-OUT  2022/09/04 16:18        116    80F1AF380       12  8023ED8B0
# 26   1  FAN-OUT  2022/09/04 16:40        116    80F1AF380   148348  81203F670
# 27   1  FAN-OUT  2022/09/04 18:23        116    80F1AF380    24515  8043B2310
#
#     amount_received receiving_currency  amount_paid   payment_currency  \
# 16         16502.02  Australian Dollar     16502.02  Australian Dollar
# 17         17193.07          US Dollar     17193.07          US Dollar
# 18        278872.19                Yen    278872.19                Yen
# 19          3620.93               Euro      3620.93               Euro
# 20          5430.89           UK Pound      5430.89           UK Pound
# 21           284.56               Euro       284.56               Euro
# 22         17454.74          US Dollar     17454.74          US Dollar
# 23         53268.16             Shekel     53268.16             Shekel
# 24          6986.50          US Dollar      6986.50          US Dollar
# 25         19725.23          US Dollar     19725.23          US Dollar
# 26         28865.06        Saudi Riyal     28865.06        Saudi Riyal
# 27          5150.77          US Dollar      5150.77          US Dollar
#
#    payment_format  is_laundering               category
# 16            ACH              1  Max 12-degree Fan-Out
# 17            ACH              1  Max 12-degree Fan-Out
# 18            ACH              1  Max 12-degree Fan-Out
# 19            ACH              1  Max 12-degree Fan-Out
# 20            ACH              1  Max 12-degree Fan-Out
# 21            ACH              1  Max 12-degree Fan-Out
# 22            ACH              1  Max 12-degree Fan-Out
# 23            ACH              1  Max 12-degree Fan-Out
# 24            ACH              1  Max 12-degree Fan-Out
# 25            ACH              1  Max 12-degree Fan-Out
# 26            ACH              1  Max 12-degree Fan-Out
# 27            ACH              1  Max 12-degree Fan-Out

# %% [markdown]
# Why is not the transactions with id 32 considered the account 811C599A0 like in the id 41?

# %% [markdown]
# ### Conclusions

# %% [markdown]
# The following features might be useful for fan-out:
# - for each from_account, the number of outgoing nodes from the same bank and all out-node could have different:
#     * receiving_currency (same as payment_currency in the same transaction)
#     * payment_currency
#     * payment_format
# - transactions to the same account (& same bank) can't be considered same fan-out
# - some fan-outs are 1-degree: there are other transactions that are the same (different amounts and timestamps)
# - check if there is an identical transaction with different amounts at the same time
# - there must be at most 4 days between the first transaction and the last in the series

# %% [markdown]
# # FAN-IN (fig. b)

# %% [markdown]
# It is the opposite of FAN-OUT

# %%
fan_in = ds[ds.type=='FAN-IN']

# %% [markdown]
# ### More than 1-degree

# %% [markdown]
# #### Example 1

# %%
fan_in0 = fan_in[fan_in.id==0]
fan_in0
# Out:
#       id    type         timestamp  from_bank from_account  to_bank  \
# 2265   0  FAN-IN  2022/09/01 04:47        222    811B83280      119
# 2266   0  FAN-IN  2022/09/04 16:56      48309    811C599A0      119
#
#      to_account  amount_received receiving_currency  amount_paid  \
# 2265  811C597B0         13148.66        Saudi Riyal     13148.66
# 2266  811C597B0         24189.19        Saudi Riyal     24189.19
#
#      payment_currency payment_format  is_laundering             category
# 2265      Saudi Riyal            ACH              1  Max 2-degree Fan-In
# 2266      Saudi Riyal            ACH              1  Max 2-degree Fan-In

# %% [markdown]
# All transactions are:
# - received from 811ED7DF0 to bank 48308
# - receiving_currency = payment_currency = Saudi Riyal
# - payment_format = ACH
# Let's try to see how many launderings there are in the dataset that reflect these characteristics

# %%
filter_dataframe("Saudi Riyal","Saudi Riyal", to_bank=48308, to_account="811ED7DF0")
# Out:
# +-------------------+---------+------------+-------+----------+---------------+------------------+-----------+----------------+--------------+-------------+-----------+
# |          timestamp|from_bank|from_account|to_bank|to_account|amount_received|receiving_currency|amount_paid|payment_currency|payment_format|is_laundering|         id|
# +-------------------+---------+------------+-------+----------+---------------+------------------+-----------+----------------+--------------+-------------+-----------+
# |2022-09-01 06:23:00|   149345|   812D1AC00|  48308| 811ED7DF0|       45346.12|       Saudi Riyal|   45346.12|     Saudi Riyal|           ACH|            1|17179935492|
# |2022-09-01 15:27:00|      223|   8119F8CC0|  48308| 811ED7DF0|       30299.15|       Saudi Riyal|   30299.15|     Saudi Riyal|           ACH|            1| 8590000904|
# |2022-09-02 01:39:00|    48309|   81235EAA0|  48308| 811ED7DF0|         8117.8|       Saudi Riyal|     8117.8|     Saudi Riyal|           ACH|            1|51539673099|
# |2022-09-02 06:36:00|    48910|   8120D49E0|  48308| 811ED7DF0|       72635.55|       Saudi Riyal|   72635.55|     Saudi Riyal|           ACH|            1|51539673100|
# |2022-09-02 09:57:00|   249176|   81235EC40|  48308| 811ED7DF0|       14363.22|       Saudi Riyal|   14363.22|     Saudi Riyal|           ACH|            1|51539673101|
# |2022-09-02 13:13:00|   148348|   81235EE30|  48308| 811ED7DF0|       11495.93|       Saudi Riyal|   11495.93|     Saudi Riyal|           ACH|            1|51539673102|
# |2022-09-02 18:31:00|      118|   811A67510|  48308| 811ED7DF0|       47915.92|       Saudi Riyal|   47915.92|     Saudi Riyal|           ACH|            1|17179935493|
# |2022-09-03 07:57:00|   148016|   811FCA7B0|  48308| 811ED7DF0|       18841.21|       Saudi Riyal|   18841.21|     Saudi Riyal|           ACH|            1|      66171|
# |2022-09-03 09:14:00|      119|   8000DA7D0|  48308| 811ED7DF0|       65196.57|       Saudi Riyal|   65196.57|     Saudi Riyal|           ACH|            1|60129607795|
# |2022-09-03 16:24:00|      223|   811EDA940|  48308| 811ED7DF0|       71981.58|       Saudi Riyal|   71981.58|     Saudi Riyal|           ACH|            1|51539673103|
# |2022-09-03 17:28:00|    48526|   8120D4990|  48308| 811ED7DF0|       66492.84|       Saudi Riyal|   66492.84|     Saudi Riyal|           ACH|            1| 8590000905|
# |2022-09-04 05:17:00|      223|   812D1A410|  48308| 811ED7DF0|       20597.36|       Saudi Riyal|   20597.36|     Saudi Riyal|           ACH|            1|42949739022|
# |2022-09-04 07:10:00|   249118|   812D1A650|  48308| 811ED7DF0|      291133.92|       Saudi Riyal|  291133.92|     Saudi Riyal|           ACH|            1|42949739023|
# |2022-09-04 11:44:00|   251264|   812D1B280|  48308| 811ED7DF0|       66719.61|       Saudi Riyal|   66719.61|     Saudi Riyal|           ACH|            1|17179935494|
# |2022-09-04 12:55:00|      118|   811A67510|  48308| 811ED7DF0|        3756.51|       Saudi Riyal|    3756.51|     Saudi Riyal|           ACH|            1|60129789444|
# |2022-09-04 12:55:00|      118|   811A67510|  48308| 811ED7DF0|       19753.45|       Saudi Riyal|   19753.45|     Saudi Riyal|           ACH|            0|34359985592|
# |2022-09-04 15:28:00|      223|   811A65E30|  48308| 811ED7DF0|       37976.48|       Saudi Riyal|   37976.48|     Saudi Riyal|           ACH|            1| 8590000906|
# |2022-09-05 01:18:00|      121|   811E03C30|  48308| 811ED7DF0|       30922.13|       Saudi Riyal|   30922.13|     Saudi Riyal|           ACH|            1|42949739024|
# |2022-09-07 06:16:00|   249176|   81235EC40|  48308| 811ED7DF0|       46603.28|       Saudi Riyal|   46603.28|     Saudi Riyal|           ACH|            1|     338985|
# |2022-09-10 10:32:00|    48308|   811EDA7A0|  48308| 811ED7DF0|        15339.0|       Saudi Riyal|    15339.0|     Saudi Riyal|           ACH|            1|42950262406|
# +-------------------+---------+------------+-------+----------+---------------+------------------+-----------+----------------+--------------+-------------+-----------+
# only showing top 20 rows

# %%
fan_in.columns
# Out:
# Index(['id', 'type', 'timestamp', 'from_bank', 'from_account', 'to_bank',
#        'to_account', 'amount_received', 'receiving_currency', 'amount_paid',
#        'payment_currency', 'payment_format', 'is_laundering', 'category'],
#       dtype='object')

# %% [markdown]
# Here we see that there is only one transaction that is not laundering. If we notice, this transaction happens at the same time as the transaction above, which is laundering

# %% [markdown]
# #### Esempio 2

# %%
fan_in1 = fan_in[fan_in.id==2]
display(fan_in1)
filter_dataframe("US Dollar","US Dollar", to_bank=1362, to_account="8001ECD70")
# Out:
#       id    type         timestamp  from_bank from_account  to_bank  \
# 2283   2  FAN-IN  2022/09/01 08:21         11    8001027C0     1362
# 2284   2  FAN-IN  2022/09/01 11:34         20    800246FC0     1362
# 2285   2  FAN-IN  2022/09/01 12:19         20    800060420     1362
# 2286   2  FAN-IN  2022/09/02 04:06         20    800283B60     1362
# 2287   2  FAN-IN  2022/09/02 12:55         12    800137450     1362
# 2288   2  FAN-IN  2022/09/02 14:13         12    800117590     1362
# 2289   2  FAN-IN  2022/09/03 14:57       1490    800A180A0     1362
# 2290   2  FAN-IN  2022/09/04 09:59          1    800056160     1362
# 2291   2  FAN-IN  2022/09/04 14:46         23    8001D7610     1362
# 2292   2  FAN-IN  2022/09/04 17:08         12    800205030     1362
#
#      to_account  amount_received receiving_currency  amount_paid  \
# 2283  8001ECD70          8340.74          US Dollar      8340.74
# 2284  8001ECD70         15524.16          US Dollar     15524.16
# 2285  8001ECD70         16367.46          US Dollar     16367.46
# 2286  8001ECD70          1869.72          US Dollar      1869.72
# 2287  8001ECD70          5073.01          US Dollar      5073.01
# 2288  8001ECD70         16050.64          US Dollar     16050.64
# 2289  8001ECD70           161.35          US Dollar       161.35
# 2290  8001ECD70          4383.81          US Dollar      4383.81
# 2291  8001ECD70          3757.42          US Dollar      3757.42
# 2292  8001ECD70      11896790.65          US Dollar  11896790.65
#
#      payment_currency payment_format  is_laundering              category
# 2283        US Dollar            ACH              1  Max 10-degree Fan-In
# 2284        US Dollar            ACH              1  Max 10-degree Fan-In
# 2285        US Dollar            ACH              1  Max 10-degree Fan-In
# 2286        US Dollar            ACH              1  Max 10-degree Fan-In
# 2287        US Dollar            ACH              1  Max 10-degree Fan-In
# 2288        US Dollar            ACH              1  Max 10-degree Fan-In
# 2289        US Dollar            ACH              1  Max 10-degree Fan-In
# 2290        US Dollar            ACH              1  Max 10-degree Fan-In
# 2291        US Dollar            ACH              1  Max 10-degree Fan-In
# 2292        US Dollar            ACH              1  Max 10-degree Fan-In
# +-------------------+---------+------------+-------+----------+---------------+------------------+-------------+----------------+--------------+-------------+-----------+
# |          timestamp|from_bank|from_account|to_bank|to_account|amount_received|receiving_currency|  amount_paid|payment_currency|payment_format|is_laundering|         id|
# +-------------------+---------+------------+-------+----------+---------------+------------------+-------------+----------------+--------------+-------------+-----------+
# |2022-09-01 02:29:00|       10|   8001882D0|   1362| 8001ECD70|          44.43|         US Dollar|        44.43|       US Dollar|           ACH|            0|51539654555|
# |2022-09-01 08:21:00|       11|   8001027C0|   1362| 8001ECD70|        8340.74|         US Dollar|      8340.74|       US Dollar|           ACH|            1|42949746096|
# |2022-09-01 11:34:00|       20|   800246FC0|   1362| 8001ECD70|       15524.16|         US Dollar|     15524.16|       US Dollar|           ACH|            1|34359811387|
# |2022-09-01 12:19:00|       20|   800060420|   1362| 8001ECD70|       16367.46|         US Dollar|     16367.46|       US Dollar|           ACH|            1|17179942767|
# |2022-09-02 01:56:00|      220|   800146310|   1362| 8001ECD70|     2148312.26|         US Dollar|   2148312.26|       US Dollar|           ACH|            0| 8590081891|
# |2022-09-02 04:06:00|       20|   800283B60|   1362| 8001ECD70|        1869.72|         US Dollar|      1869.72|       US Dollar|           ACH|            1|      73515|
# |2022-09-02 12:55:00|       12|   800137450|   1362| 8001ECD70|        5073.01|         US Dollar|      5073.01|       US Dollar|           ACH|            1| 8590008218|
# |2022-09-02 14:13:00|       12|   800117590|   1362| 8001ECD70|       16050.64|         US Dollar|     16050.64|       US Dollar|           ACH|            1| 8590008219|
# |2022-09-02 19:33:00|       10|   8001882D0|   1362| 8001ECD70|          44.43|         US Dollar|        44.43|       US Dollar|           ACH|            0|25770020340|
# |2022-09-03 08:42:00|       10|   8001882D0|   1362| 8001ECD70|          44.43|         US Dollar|        44.43|       US Dollar|           ACH|            0|42949916659|
# |2022-09-03 14:57:00|     1490|   800A180A0|   1362| 8001ECD70|         161.35|         US Dollar|       161.35|       US Dollar|           ACH|            1| 8590008220|
# |2022-09-04 09:59:00|        1|   800056160|   1362| 8001ECD70|        4383.81|         US Dollar|      4383.81|       US Dollar|           ACH|            1|25769877355|
# |2022-09-04 12:09:00|       10|   8001882D0|   1362| 8001ECD70|          44.43|         US Dollar|        44.43|       US Dollar|           ACH|            0|51539881527|
# |2022-09-04 14:46:00|       23|   8001D7610|   1362| 8001ECD70|        3757.42|         US Dollar|      3757.42|       US Dollar|           ACH|            1|25769877356|
# |2022-09-04 17:08:00|       12|   800205030|   1362| 8001ECD70|  1.189679065E7|         US Dollar|1.189679065E7|       US Dollar|           ACH|            1|51539680361|
# |2022-09-05 14:45:00|       10|   8001882D0|   1362| 8001ECD70|          44.43|         US Dollar|        44.43|       US Dollar|           ACH|            0|60129864226|
# |2022-09-06 20:13:00|       10|   8001882D0|   1362| 8001ECD70|          44.43|         US Dollar|        44.43|       US Dollar|           ACH|            0| 8590331710|
# |2022-09-07 20:36:00|       10|   8001882D0|   1362| 8001ECD70|          44.43|         US Dollar|        44.43|       US Dollar|           ACH|            0|17180327673|
# |2022-09-08 14:17:00|       10|   8001882D0|   1362| 8001ECD70|          44.43|         US Dollar|        44.43|       US Dollar|           ACH|            0|17180371996|
# |2022-09-09 01:00:00|       10|   8001882D0|   1362| 8001ECD70|          44.43|         US Dollar|        44.43|       US Dollar|           ACH|            0|60130073293|
# +-------------------+---------+------------+-------+----------+---------------+------------------+-------------+----------------+--------------+-------------+-----------+
# only showing top 20 rows

# %% [markdown]
# Here we can see that all transactions between 8001882D0 and 8001ECD70 are not laundering

# %% [markdown]
# ### 1-degree

# %%
fan_in = ds[ds.type=='FAN-IN']
fan_in1degree = fan_in[fan_in.category=="Max 1-degree Fan-In"]
fan_in1degree
# Out:
#       id    type         timestamp  from_bank from_account  to_bank  \
# 2295   4  FAN-IN  2022/09/01 15:06        119    812A09CF0    49365
# 2416  18  FAN-IN  2022/09/05 07:32      49365    812A09D40      119
# 2537  33  FAN-IN  2022/09/09 14:15     249176    812A70ED0    49508
# 2538  34  FAN-IN  2022/09/09 15:15      15231    80266F880    23691
#
#      to_account  amount_received receiving_currency  amount_paid  \
# 2295  812A09D40         36537.53        Saudi Riyal     36537.53
# 2416  812A09CF0         70400.86        Saudi Riyal     70400.86
# 2537  812A70E80         71496.43        Saudi Riyal     71496.43
# 2538  8021353D0          1549.19               Euro      1549.19
#
#      payment_currency payment_format  is_laundering             category
# 2295      Saudi Riyal            ACH              1  Max 1-degree Fan-In
# 2416      Saudi Riyal            ACH              1  Max 1-degree Fan-In
# 2537      Saudi Riyal            ACH              1  Max 1-degree Fan-In
# 2538             Euro            ACH              1  Max 1-degree Fan-In

# %% [markdown]
# Taking into account all fan outs with 1 degree, we see that these transactions are the same, but with different amounts

# %%
fan_out1degree
# Out:
#      id     type         timestamp  from_bank from_account  to_bank  \
# 73    7  FAN-OUT  2022/09/02 03:04      15231    80266F880    23691
# 113  15  FAN-OUT  2022/09/03 22:15      15231    80266F880    23691
# 132  19  FAN-OUT  2022/09/04 15:30      15231    80266F880    23691
# 154  24  FAN-OUT  2022/09/06 10:04      49365    812A09D40      119
# 204  29  FAN-OUT  2022/09/07 00:21        119    812A09CF0    49365
# 205  30  FAN-OUT  2022/09/07 00:53      23691    8021353D0    15231
# 280  40  FAN-OUT  2022/09/09 15:30     249176    812A70ED0    49508
# 295  43  FAN-OUT  2022/09/09 18:42      50202    812D129C0      222
#
#     to_account  amount_received receiving_currency  amount_paid  \
# 73   8021353D0         15536.84               Euro     15536.84
# 113  8021353D0         12592.29               Euro     12592.29
# 132  8021353D0          8092.93               Euro      8092.93
# 154  812A09CF0         32736.73        Saudi Riyal     32736.73
# 204  812A09D40         12260.49        Saudi Riyal     12260.49
# 205  80266F880          6149.56               Euro      6149.56
# 280  812A70E80         17579.07        Saudi Riyal     17579.07
# 295  812D127D0         70077.51        Saudi Riyal     70077.51
#
#     payment_currency payment_format  is_laundering              category
# 73              Euro            ACH              1  Max 1-degree Fan-Out
# 113             Euro            ACH              1  Max 1-degree Fan-Out
# 132             Euro            ACH              1  Max 1-degree Fan-Out
# 154      Saudi Riyal            ACH              1  Max 1-degree Fan-Out
# 204      Saudi Riyal            ACH              1  Max 1-degree Fan-Out
# 205             Euro            ACH              1  Max 1-degree Fan-Out
# 280      Saudi Riyal            ACH              1  Max 1-degree Fan-Out
# 295      Saudi Riyal            ACH              1  Max 1-degree Fan-Out

# %% [markdown]
# ### Final understanding

# %%
features_fan_in = ['timestamp','to_account','to_bank','receiving_currency','payment_currency','category','payment_format']
fan_inDF = spark.createDataFrame(fan_in)
fan_inDF = fan_inDF.withColumn("timestamp", to_timestamp(col("timestamp"), "yyyy/MM/dd HH:mm"))
fan_inDF = fan_inDF.select(features_fan_in)\
    .groupBy('to_account','to_bank','receiving_currency','payment_currency','category','payment_format')\
        .agg(count('*').alias('count'), 
             min('timestamp').alias('min_ts'),
             max('timestamp').alias('max_ts'))\
            .select('to_account','to_bank','receiving_currency','payment_currency','category','count','payment_format','min_ts','max_ts')

fan_inDF.withColumn('timestamp_range', datediff(col('max_ts'), col('min_ts'))).orderBy('category').show(truncate=False)
# Out:
# +----------+-------+------------------+-----------------+--------------------+-----+--------------+-------------------+-------------------+---------------+
# |to_account|to_bank|receiving_currency|payment_currency |category            |count|payment_format|min_ts             |max_ts             |timestamp_range|
# +----------+-------+------------------+-----------------+--------------------+-----+--------------+-------------------+-------------------+---------------+
# |812A09D40 |49365  |Saudi Riyal       |Saudi Riyal      |Max 1-degree Fan-In |1    |ACH           |2022-09-01 15:06:00|2022-09-01 15:06:00|0              |
# |812A09CF0 |119    |Saudi Riyal       |Saudi Riyal      |Max 1-degree Fan-In |1    |ACH           |2022-09-05 07:32:00|2022-09-05 07:32:00|0              |
# |812A70E80 |49508  |Saudi Riyal       |Saudi Riyal      |Max 1-degree Fan-In |1    |ACH           |2022-09-09 14:15:00|2022-09-09 14:15:00|0              |
# |8021353D0 |23691  |Euro              |Euro             |Max 1-degree Fan-In |1    |ACH           |2022-09-09 15:15:00|2022-09-09 15:15:00|0              |
# |8001ECD70 |1362   |US Dollar         |US Dollar        |Max 10-degree Fan-In|10   |ACH           |2022-09-01 08:21:00|2022-09-04 17:08:00|3              |
# |80E27AA10 |25866  |Euro              |Euro             |Max 10-degree Fan-In|10   |ACH           |2022-09-04 00:26:00|2022-09-07 16:03:00|3              |
# |80BB289A0 |29814  |Euro              |Euro             |Max 10-degree Fan-In|10   |ACH           |2022-09-04 15:13:00|2022-09-08 15:02:00|4              |
# |810C289B0 |17863  |Euro              |Euro             |Max 10-degree Fan-In|10   |ACH           |2022-09-08 11:27:00|2022-09-12 09:18:00|4              |
# |800E3D880 |11056  |Euro              |Euro             |Max 11-degree Fan-In|11   |ACH           |2022-09-06 17:05:00|2022-09-10 07:47:00|4              |
# |80A2DF610 |27755  |Australian Dollar |Australian Dollar|Max 11-degree Fan-In|11   |ACH           |2022-09-09 05:45:00|2022-09-12 18:54:00|3              |
# |80145D800 |13145  |US Dollar         |US Dollar        |Max 12-degree Fan-In|12   |ACH           |2022-09-04 10:24:00|2022-09-08 10:11:00|4              |
# |80F454910 |41407  |Swiss Franc       |Swiss Franc      |Max 12-degree Fan-In|12   |ACH           |2022-09-10 21:02:00|2022-09-14 19:51:00|4              |
# |8053168D0 |21918  |Euro              |Euro             |Max 13-degree Fan-In|13   |ACH           |2022-09-03 03:58:00|2022-09-06 18:23:00|3              |
# |807DD0FB0 |111764 |US Dollar         |US Dollar        |Max 13-degree Fan-In|13   |ACH           |2022-09-03 16:10:00|2022-09-07 12:17:00|4              |
# |803173180 |7042   |US Dollar         |US Dollar        |Max 13-degree Fan-In|13   |ACH           |2022-09-04 23:45:00|2022-09-08 12:03:00|4              |
# |801A21E40 |14325  |US Dollar         |US Dollar        |Max 13-degree Fan-In|13   |ACH           |2022-09-08 07:32:00|2022-09-11 20:40:00|3              |
# |8001D5B50 |11     |Euro              |Euro             |Max 13-degree Fan-In|13   |ACH           |2022-09-09 11:24:00|2022-09-13 05:33:00|4              |
# |80E6BFD50 |225263 |US Dollar         |US Dollar        |Max 13-degree Fan-In|13   |ACH           |2022-09-10 11:46:00|2022-09-13 19:05:00|3              |
# |80098DC70 |410    |Euro              |Euro             |Max 15-degree Fan-In|15   |ACH           |2022-09-06 02:29:00|2022-09-10 02:05:00|4              |
# |811ED7DF0 |48308  |Saudi Riyal       |Saudi Riyal      |Max 16-degree Fan-In|16   |ACH           |2022-09-01 06:23:00|2022-09-05 01:18:00|4              |
# +----------+-------+------------------+-----------------+--------------------+-----+--------------+-------------------+-------------------+---------------+
# only showing top 20 rows

# %% [markdown]
# ### Conclusions

# %% [markdown]
# The following features might be useful for fan-in:
# - for each to_account, the number of incoming nodes to the same bank and all in node must have the same:
#     * receiving_currency
#     * payment_currency
#     * payment_format
# - some fan-ins are 1-degree: there are other transactions that are the same (different amounts and timestamps)
# - some recurring transactions between two accounts are not laundering
# - there must be at most 4 days between the first transaction and the last in the series

# %% [markdown]
# # GATHER-SCATTER & SCATTER-GATHER
# These two essentially take fan-in and fan-out and put them together: gather-scatter arises from a fan-followed by a fan-out, conversely scatter-gather

# %%
gather_scatter = ds[ds.type=="GATHER-SCATTER"]
scatter_gather = ds[ds.type=="SCATTER-GATHER"]

# %% [markdown]
# ## GATHER-SCATTER

# %% [markdown]
# Gather scatter exists if there are fan-ins followed by fan-outs.
#
# We can see the 2 examples below.

# %% [markdown]
# #### Example 1
# Example with a 13 degree fan-in followed by a 4 degree fan-out

# %%
gather_scatter[gather_scatter.id==1].sort_values('timestamp')
# Out:
#      id            type         timestamp  from_bank from_account  to_bank  \
# 634   1  GATHER-SCATTER  2022/09/01 00:43      12963    80296CA20   241869
# 635   1  GATHER-SCATTER  2022/09/01 07:15       1588    801ABC430   241869
# 636   1  GATHER-SCATTER  2022/09/01 15:25       3051    8012E62B0   241869
# 637   1  GATHER-SCATTER  2022/09/01 15:32       2843    8043B07C0   241869
# 638   1  GATHER-SCATTER  2022/09/01 17:25      29788    80399CED0   241869
# 639   1  GATHER-SCATTER  2022/09/02 07:29      28183    80BF4C160   241869
# 640   1  GATHER-SCATTER  2022/09/02 15:44     131167    80C21E690   241869
# 641   1  GATHER-SCATTER  2022/09/03 03:54     129974    80FE25690   241869
# 642   1  GATHER-SCATTER  2022/09/03 07:12       3051    806A3D750   241869
# 643   1  GATHER-SCATTER  2022/09/03 11:07      13157    805CA5A30   241869
# 644   1  GATHER-SCATTER  2022/09/03 14:28       1047    8031B5390   241869
# 645   1  GATHER-SCATTER  2022/09/04 14:07     214050    80543C3C0   241869
# 646   1  GATHER-SCATTER  2022/09/04 16:21       1501    808C45FE0   241869
# 647   1  GATHER-SCATTER  2022/09/04 16:37     241869    80F390FC0     7548
# 648   1  GATHER-SCATTER  2022/09/04 17:23     241869    80F390FC0     1467
# 649   1  GATHER-SCATTER  2022/09/06 18:07     241869    80F390FC0    22736
# 650   1  GATHER-SCATTER  2022/09/06 19:16     241869    80F390FC0   129974
#
#     to_account  amount_received receiving_currency  amount_paid  \
# 634  80F390FC0         12562.68        Swiss Franc     12562.68
# 635  80F390FC0         10475.35        Swiss Franc     10475.35
# 636  80F390FC0         13315.35        Swiss Franc     13315.35
# 637  80F390FC0          7999.49        Swiss Franc      7999.49
# 638  80F390FC0          8430.98        Swiss Franc      8430.98
# 639  80F390FC0           295.90        Swiss Franc       295.90
# 640  80F390FC0          3354.50        Swiss Franc      3354.50
# 641  80F390FC0          9547.03        Swiss Franc      9547.03
# 642  80F390FC0          2024.65        Swiss Franc      2024.65
# 643  80F390FC0          4513.56        Swiss Franc      4513.56
# 644  80F390FC0         12427.99        Swiss Franc     12427.99
# 645  80F390FC0          1514.49        Swiss Franc      1514.49
# 646  80F390FC0         10058.54        Swiss Franc     10058.54
# 647  805284730         11674.83               Euro     11674.83
# 648  801D43090          4832.76          US Dollar      4832.76
# 649  807DC76A0          6240.05          US Dollar      6240.05
# 650  80E0D4970          7782.25          US Dollar      7782.25
#
#     payment_currency payment_format  is_laundering              category
# 634      Swiss Franc            ACH              1  Max 13-degree Fan-In
# 635      Swiss Franc            ACH              1  Max 13-degree Fan-In
# 636      Swiss Franc            ACH              1  Max 13-degree Fan-In
# 637      Swiss Franc            ACH              1  Max 13-degree Fan-In
# 638      Swiss Franc            ACH              1  Max 13-degree Fan-In
# 639      Swiss Franc            ACH              1  Max 13-degree Fan-In
# 640      Swiss Franc            ACH              1  Max 13-degree Fan-In
# 641      Swiss Franc            ACH              1  Max 13-degree Fan-In
# 642      Swiss Franc            ACH              1  Max 13-degree Fan-In
# 643      Swiss Franc            ACH              1  Max 13-degree Fan-In
# 644      Swiss Franc            ACH              1  Max 13-degree Fan-In
# 645      Swiss Franc            ACH              1  Max 13-degree Fan-In
# 646      Swiss Franc            ACH              1  Max 13-degree Fan-In
# 647             Euro            ACH              1  Max 13-degree Fan-In
# 648        US Dollar            ACH              1  Max 13-degree Fan-In
# 649        US Dollar            ACH              1  Max 13-degree Fan-In
# 650        US Dollar            ACH              1  Max 13-degree Fan-In

# %% [markdown]
# In the dataset gather-scatter referring to an account are marked by the same id. For example, taking into accout the id equal to 1 we have 13 fan-in to 80F390FC0 and then it transfers the money to other 4 accounts.
#
# All of the fan-in transactions have same currencies, while outgoings transaction have the same currencies in a single transaction while they are different between different transactions.
#
# **Fan-in and fan-out degrees can be different.**

# %% [markdown]
# #### Example 2

# %%
gather_scatter[gather_scatter.id==10]
# Out:
#      id            type         timestamp  from_bank from_account  to_bank  \
# 779  10  GATHER-SCATTER  2022/09/02 23:18      23537    801BE1590       12
# 780  10  GATHER-SCATTER  2022/09/03 00:57       8074    80803C930       12
# 781  10  GATHER-SCATTER  2022/09/03 11:32       2991    806CF1310       12
# 782  10  GATHER-SCATTER  2022/09/04 17:03         11    80028E6D0       12
# 783  10  GATHER-SCATTER  2022/09/04 18:24         15    80A2DE560       12
# 784  10  GATHER-SCATTER  2022/09/05 11:20      19329    8048E30F0       12
# 785  10  GATHER-SCATTER  2022/09/05 13:10      26624    80BAEB110       12
# 786  10  GATHER-SCATTER  2022/09/05 15:30      29279    8066C7E10       12
# 787  10  GATHER-SCATTER  2022/09/05 18:44     116214    80DDCA6A0       12
# 788  10  GATHER-SCATTER  2022/09/05 23:55      33872    80C73E400       12
# 789  10  GATHER-SCATTER  2022/09/06 02:28      10441    80EBE2F00       12
# 790  10  GATHER-SCATTER  2022/09/06 12:20      19023    80514C390       12
# 791  10  GATHER-SCATTER  2022/09/06 13:26       1241    801228520       12
# 792  10  GATHER-SCATTER  2022/09/06 14:06         12    80226C7A0       12
# 793  10  GATHER-SCATTER  2022/09/06 12:20         12    8010D4440    26818
# 794  10  GATHER-SCATTER  2022/09/07 06:16         12    8010D4440    17708
# 795  10  GATHER-SCATTER  2022/09/07 07:38         12    8010D4440    29715
# 796  10  GATHER-SCATTER  2022/09/07 17:29         12    8010D4440     5836
# 797  10  GATHER-SCATTER  2022/09/08 02:03         12    8010D4440    13516
# 798  10  GATHER-SCATTER  2022/09/08 13:12         12    8010D4440       23
# 799  10  GATHER-SCATTER  2022/09/09 05:38         12    8010D4440       22
# 800  10  GATHER-SCATTER  2022/09/09 12:40         12    8010D4440    28726
# 801  10  GATHER-SCATTER  2022/09/10 05:31         12    8010D4440   137218
# 802  10  GATHER-SCATTER  2022/09/10 11:00         12    8010D4440   132554
#
#     to_account  amount_received receiving_currency  amount_paid  \
# 779  8010D4440         11002.46          US Dollar     11002.46
# 780  8010D4440         13705.30          US Dollar     13705.30
# 781  8010D4440          9786.57          US Dollar      9786.57
# 782  8010D4440         13764.67          US Dollar     13764.67
# 783  8010D4440         17065.68          US Dollar     17065.68
# 784  8010D4440         17498.02          US Dollar     17498.02
# 785  8010D4440          1291.27          US Dollar      1291.27
# 786  8010D4440         16614.28          US Dollar     16614.28
# 787  8010D4440          1231.08          US Dollar      1231.08
# 788  8010D4440          9016.37          US Dollar      9016.37
# 789  8010D4440         14746.07          US Dollar     14746.07
# 790  8010D4440           134.14          US Dollar       134.14
# 791  8010D4440         14777.72          US Dollar     14777.72
# 792  8010D4440          5162.15          US Dollar      5162.15
# 793  8021F0F10          1981.18               Euro      1981.18
# 794  80CD41030         18721.33          US Dollar     18721.33
# 795  80C2D6120         46499.47               Yuan     46499.47
# 796  80485EDA0         16509.39          US Dollar     16509.39
# 797  801D20BB0           114.67               Euro       114.67
# 798  8043CA5F0          3814.78               Euro      3814.78
# 799  801E7B850          4773.42               Euro      4773.42
# 800  809379140          6828.41               Euro      6828.41
# 801  80EB2C3F0          1380.75        Swiss Franc      1380.75
# 802  80D31F5E0         81592.54          US Dollar     81592.54
#
#     payment_currency payment_format  is_laundering              category
# 779        US Dollar            ACH              1  Max 14-degree Fan-In
# 780        US Dollar            ACH              1  Max 14-degree Fan-In
# 781        US Dollar            ACH              1  Max 14-degree Fan-In
# 782        US Dollar            ACH              1  Max 14-degree Fan-In
# 783        US Dollar            ACH              1  Max 14-degree Fan-In
# 784        US Dollar            ACH              1  Max 14-degree Fan-In
# 785        US Dollar            ACH              1  Max 14-degree Fan-In
# 786        US Dollar            ACH              1  Max 14-degree Fan-In
# 787        US Dollar            ACH              1  Max 14-degree Fan-In
# 788        US Dollar            ACH              1  Max 14-degree Fan-In
# 789        US Dollar            ACH              1  Max 14-degree Fan-In
# 790        US Dollar            ACH              1  Max 14-degree Fan-In
# 791        US Dollar            ACH              1  Max 14-degree Fan-In
# 792        US Dollar            ACH              1  Max 14-degree Fan-In
# 793             Euro            ACH              1  Max 14-degree Fan-In
# 794        US Dollar            ACH              1  Max 14-degree Fan-In
# 795             Yuan            ACH              1  Max 14-degree Fan-In
# 796        US Dollar            ACH              1  Max 14-degree Fan-In
# 797             Euro            ACH              1  Max 14-degree Fan-In
# 798             Euro            ACH              1  Max 14-degree Fan-In
# 799             Euro            ACH              1  Max 14-degree Fan-In
# 800             Euro            ACH              1  Max 14-degree Fan-In
# 801      Swiss Franc            ACH              1  Max 14-degree Fan-In
# 802        US Dollar            ACH              1  Max 14-degree Fan-In

# %%
gather_scatter[(gather_scatter.to_account!="811C599A0") & (gather_scatter.from_account=="811C599A0")]# & (gather_scatter.category=="Max 3-degree Fan-In")]
# Out:
#       id            type         timestamp  from_bank from_account  to_bank  \
# 633    0  GATHER-SCATTER  2022/09/04 14:59      48309    811C599A0      119
# 871   15  GATHER-SCATTER  2022/09/04 16:03      48309    811C599A0   150240
# 993   26  GATHER-SCATTER  2022/09/08 19:12      48309    811C599A0      119
# 1040  30  GATHER-SCATTER  2022/09/06 23:05      48309    811C599A0      119
# 1061  32  GATHER-SCATTER  2022/09/12 15:24      48309    811C599A0      222
# 1062  32  GATHER-SCATTER  2022/09/13 18:47      48309    811C599A0   150240
# 1335  49  GATHER-SCATTER  2022/09/14 13:40      48309    811C599A0      119
# 1337  49  GATHER-SCATTER  2022/09/17 02:45      48309    811C599A0      222
#
#      to_account  amount_received receiving_currency   amount_paid  \
# 633   811C597B0     6.437945e+04        Saudi Riyal  6.437945e+04
# 871   812D22980     1.453912e+08        Saudi Riyal  1.453912e+08
# 993   811C597B0     4.825906e+04        Saudi Riyal  4.825906e+04
# 1040  811C597B0     1.187848e+04        Saudi Riyal  1.187848e+04
# 1061  811B83280     1.953036e+04        Saudi Riyal  1.953036e+04
# 1062  812D22980     5.120163e+04        Saudi Riyal  5.120163e+04
# 1335  811C597B0     3.036054e+04        Saudi Riyal  3.036054e+04
# 1337  811B83280     3.482231e+04        Saudi Riyal  3.482231e+04
#
#      payment_currency payment_format  is_laundering             category
# 633       Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 871       Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 993       Saudi Riyal            ACH              1  Max 2-degree Fan-In
# 1040      Saudi Riyal            ACH              1  Max 2-degree Fan-In
# 1061      Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 1062      Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 1335      Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 1337      Saudi Riyal            ACH              1  Max 3-degree Fan-In

# %%
gather_scatter[(gather_scatter.from_account=="811C597B0")]
# Out:
#       id            type         timestamp  from_bank from_account  to_bank  \
# 629    0  GATHER-SCATTER  2022/09/01 00:04        119    811C597B0    48309
# 869   15  GATHER-SCATTER  2022/09/03 12:22        119    811C597B0   150240
# 919   19  GATHER-SCATTER  2022/09/08 14:50        119    811C597B0      222
# 992   26  GATHER-SCATTER  2022/09/08 06:38        119    811C597B0    48309
# 1042  30  GATHER-SCATTER  2022/09/07 09:06        119    811C597B0    48309
# 1043  30  GATHER-SCATTER  2022/09/10 23:17        119    811C597B0      119
# 1044  30  GATHER-SCATTER  2022/09/11 07:32        119    811C597B0      222
# 1059  32  GATHER-SCATTER  2022/09/11 16:43        119    811C597B0    48309
# 1333  49  GATHER-SCATTER  2022/09/13 22:14        119    811C597B0    48309
#
#      to_account  amount_received receiving_currency  amount_paid  \
# 629   811C599A0         34254.65        Saudi Riyal     34254.65
# 869   812D22980         22910.80        Saudi Riyal     22910.80
# 919   811B83280          5905.43        Saudi Riyal      5905.43
# 992   811C599A0         15786.73        Saudi Riyal     15786.73
# 1042  811C599A0           657.36        Saudi Riyal       657.36
# 1043  811C597B0      14144807.18        Saudi Riyal  14144807.18
# 1044  811B83280         31324.25        Saudi Riyal     31324.25
# 1059  811C599A0          7043.12        Saudi Riyal      7043.12
# 1333  811C599A0         55691.86        Saudi Riyal     55691.86
#
#      payment_currency payment_format  is_laundering             category
# 629       Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 869       Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 919       Saudi Riyal            ACH              1  Max 2-degree Fan-In
# 992       Saudi Riyal            ACH              1  Max 2-degree Fan-In
# 1042      Saudi Riyal            ACH              1  Max 2-degree Fan-In
# 1043      Saudi Riyal            ACH              1  Max 2-degree Fan-In
# 1044      Saudi Riyal            ACH              1  Max 2-degree Fan-In
# 1059      Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 1333      Saudi Riyal            ACH              1  Max 3-degree Fan-In

# %%
gather_scatter[(gather_scatter.to_account=="811C599A0") & (gather_scatter.category=="Max 3-degree Fan-In")]
# Out:
#       id            type         timestamp  from_bank from_account  to_bank  \
# 629    0  GATHER-SCATTER  2022/09/01 00:04        119    811C597B0    48309
# 630    0  GATHER-SCATTER  2022/09/01 19:27     150240    812D22980    48309
# 631    0  GATHER-SCATTER  2022/09/04 05:06        222    811B83280    48309
# 632    0  GATHER-SCATTER  2022/09/04 05:03      48309    811C599A0    48309
# 1057  32  GATHER-SCATTER  2022/09/07 23:48     150240    812D22980    48309
# 1058  32  GATHER-SCATTER  2022/09/09 04:55        222    811B83280    48309
# 1059  32  GATHER-SCATTER  2022/09/11 16:43        119    811C597B0    48309
# 1060  32  GATHER-SCATTER  2022/09/11 05:36      48309    811C599A0    48309
# 1332  49  GATHER-SCATTER  2022/09/10 18:55        222    811B83280    48309
# 1333  49  GATHER-SCATTER  2022/09/13 22:14        119    811C597B0    48309
# 1334  49  GATHER-SCATTER  2022/09/14 17:54     150240    812D22980    48309
# 1336  49  GATHER-SCATTER  2022/09/15 13:55      48309    811C599A0    48309
#
#      to_account  amount_received receiving_currency  amount_paid  \
# 629   811C599A0         34254.65        Saudi Riyal     34254.65
# 630   811C599A0          5971.98        Saudi Riyal      5971.98
# 631   811C599A0         50445.58        Saudi Riyal     50445.58
# 632   811C599A0         48649.42        Saudi Riyal     48649.42
# 1057  811C599A0         55801.94        Saudi Riyal     55801.94
# 1058  811C599A0         70986.04        Saudi Riyal     70986.04
# 1059  811C599A0          7043.12        Saudi Riyal      7043.12
# 1060  811C599A0         52436.24        Saudi Riyal     52436.24
# 1332  811C599A0          9267.00        Saudi Riyal      9267.00
# 1333  811C599A0         55691.86        Saudi Riyal     55691.86
# 1334  811C599A0         60777.80        Saudi Riyal     60777.80
# 1336  811C599A0         46862.34        Saudi Riyal     46862.34
#
#      payment_currency payment_format  is_laundering             category
# 629       Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 630       Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 631       Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 632       Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 1057      Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 1058      Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 1059      Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 1060      Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 1332      Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 1333      Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 1334      Saudi Riyal            ACH              1  Max 3-degree Fan-In
# 1336      Saudi Riyal            ACH              1  Max 3-degree Fan-In

# %% [markdown]
# #### Conclusions
# For each transaction, compute how many transaction are directed to the same to_account with the same currencies and then count how many transactions are handled by the from_account (to_account that now sends money) to other accounts:
# - currencies are not relevant
# - consider also self payment
#
# So we need 2 features:
# - fan-in (check if I have already calculated them)
# - fan-out (check if I have already calculated them)

# %% [markdown]
# # BIPARTITE

# %%
bipartite = ds[ds.type=='BIPARTITE']
bipartite0 = bipartite[bipartite.id==0]
bipartite0
# Out:
#       id       type         timestamp  from_bank from_account  to_bank  \
# 2002   0  BIPARTITE  2022/09/01 11:03      11904    80103A420    14077
# 2003   0  BIPARTITE  2022/09/02 16:43       3489    80211F620    13265
# 2004   0  BIPARTITE  2022/09/02 12:00      21745    800A75B90        1
# 2005   0  BIPARTITE  2022/09/01 04:39          1    8010AA4F0    12719
# 2006   0  BIPARTITE  2022/09/02 08:17          1    800DD9900    11157
# 2007   0  BIPARTITE  2022/09/01 17:05       1522    800587B60     2454
# 2008   0  BIPARTITE  2022/09/01 16:19        513    801947FF0     1292
# 2009   0  BIPARTITE  2022/09/02 08:58       1244    800ACE160    21831
# 2010   0  BIPARTITE  2022/09/01 11:32       1547    8020543A0    23525
# 2011   0  BIPARTITE  2022/09/01 07:39      21575    801A58F80       11
# 2012   0  BIPARTITE  2022/09/01 09:50         20    800BBBEC0     1688
# 2013   0  BIPARTITE  2022/09/01 19:00       1502    8010647D0     2053
# 2014   0  BIPARTITE  2022/09/02 11:44      14290    801BA48E0       12
#
#      to_account  amount_received receiving_currency  amount_paid  \
# 2002  802533E40         12347.20          US Dollar     12347.20
# 2003  8019C6830         15645.62               Euro     15645.62
# 2004  80162B4B0          7687.95          US Dollar      7687.95
# 2005  8015B5F50          9495.61          US Dollar      9495.61
# 2006  8006F0580           488.77          US Dollar       488.77
# 2007  802679190          5949.73          US Dollar      5949.73
# 2008  800639010         13556.28          US Dollar     13556.28
# 2009  800AEC6D0         12580.81               Euro     12580.81
# 2010  8018DC000          4666.40               Euro      4666.40
# 2011  80048D890          5019.15               Euro      5019.15
# 2012  801732D60          9435.24          US Dollar      9435.24
# 2013  801CFFF90         10205.61          US Dollar     10205.61
# 2014  80044F690          1581.32               Euro      1581.32
#
#      payment_currency payment_format  is_laundering category
# 2002        US Dollar            ACH              1      NaN
# 2003             Euro            ACH              1      NaN
# 2004        US Dollar            ACH              1      NaN
# 2005        US Dollar            ACH              1      NaN
# 2006        US Dollar            ACH              1      NaN
# 2007        US Dollar            ACH              1      NaN
# 2008        US Dollar            ACH              1      NaN
# 2009             Euro            ACH              1      NaN
# 2010             Euro            ACH              1      NaN
# 2011             Euro            ACH              1      NaN
# 2012        US Dollar            ACH              1      NaN
# 2013        US Dollar            ACH              1      NaN
# 2014             Euro            ACH              1      NaN

# %%
dataframe.filter('from_account=="80103A420" and is_laundering==1').show()
# Out:
# +-------------------+---------+------------+-------+----------+---------------+------------------+-----------+----------------+--------------+-------------+-----------+
# |          timestamp|from_bank|from_account|to_bank|to_account|amount_received|receiving_currency|amount_paid|payment_currency|payment_format|is_laundering|         id|
# +-------------------+---------+------------+-------+----------+---------------+------------------+-----------+----------------+--------------+-------------+-----------+
# |2022-09-01 11:03:00|    11904|   80103A420|  14077| 802533E40|        12347.2|         US Dollar|    12347.2|       US Dollar|           ACH|            1|42949720883|
# +-------------------+---------+------------+-------+----------+---------------+------------------+-----------+----------------+--------------+-------------+-----------+

# %%
bipartite_df=spark.createDataFrame(bipartite) 
bipartite_df.select('type','from_account').groupBy('type','from_account').count().filter('count>1').show()
# Out:
# +---------+------------+-----+
# |     type|from_account|count|
# +---------+------------+-----+
# |BIPARTITE|   812A09D40|    3|
# |BIPARTITE|   812A09CF0|    2|
# |BIPARTITE|   811C4EDD0|    2|
# |BIPARTITE|   8021353D0|    2|
# |BIPARTITE|   811EDA940|    2|
# |BIPARTITE|   80266F880|    4|
# |BIPARTITE|   811FFF630|    2|
# |BIPARTITE|   812A70ED0|    2|
# |BIPARTITE|   800F1D640|    2|
# |BIPARTITE|   812D0C3C0|    2|
# +---------+------------+-----+

# %%
bipartite_df.select('type','to_account').groupBy('type','to_account').count().filter('count>1').show()
# Out:
# +---------+----------+-----+
# |     type|to_account|count|
# +---------+----------+-----+
# |BIPARTITE| 812A09D40|    2|
# |BIPARTITE| 812A09CF0|    3|
# |BIPARTITE| 80266F880|    2|
# |BIPARTITE| 811FCA7B0|    3|
# |BIPARTITE| 8021353D0|    4|
# |BIPARTITE| 811ED7DF0|    2|
# |BIPARTITE| 811A65E30|    2|
# |BIPARTITE| 812A70E80|    2|
# |BIPARTITE| 812D0C600|    2|
# |BIPARTITE| 80FF51600|    2|
# +---------+----------+-----+

# %% [markdown]
# The bipartite graph shows that bipartite laundering occurs when an account splits money into multiple destinations that in turn receive money from other sources.
# The dataset above shows accounts that transact more than once to another account and the account that receives money more than once.
#
# In conclusion, the bipartite recycling set does not reflect the image of the graph

# %% [markdown]
# # STACK

# %%
stack = ds[ds.type=='STACK']
# Out:
#       id   type         timestamp  from_bank from_account  to_bank to_account  \
# 1345   0  STACK  2022/09/02 12:36        223    8000DD890    40312  80F52D550
# 1346   0  STACK  2022/09/03 19:52      40312    80F52D550    23370  80BEA98A0
# 1347   0  STACK  2022/09/01 10:19      18617    8038D3520    24482  801C0F2B0
# 1348   0  STACK  2022/09/03 05:06      24482    801C0F2B0      214  80C1B9E20
# 1349   0  STACK  2022/09/01 09:22      40836    80F6B88B0    16606  8064545E0
# ...   ..    ...               ...        ...          ...      ...        ...
# 1806  41  STACK  2022/09/11 11:17       2991    8025D1EB0    27444  803C925B0
# 1807  41  STACK  2022/09/12 11:02      21142    809F26890     1729  8083CF250
# 1808  41  STACK  2022/09/12 17:43       1729    8083CF250    20846  809406BF0
# 1809  42  STACK  2022/09/12 15:41      23691    8021353D0    15231  80266F880
# 1810  42  STACK  2022/09/14 01:58      15231    80266F880    23691  8021353D0
#
#       amount_received receiving_currency  amount_paid payment_currency  \
# 1345         14153.46        Swiss Franc     14153.46      Swiss Franc
# 1346         11975.53           UK Pound     11975.53         UK Pound
# 1347         13712.96               Euro     13712.96             Euro
# 1348        333126.09       Mexican Peso    333126.09     Mexican Peso
# 1349         11800.69          US Dollar     11800.69        US Dollar
# ...               ...                ...          ...              ...
# 1806         13658.31          US Dollar     13658.31        US Dollar
# 1807        392562.58          US Dollar    392562.58        US Dollar
# 1808        335012.90               Euro    335012.90             Euro
# 1809          4409.63               Euro      4409.63             Euro
# 1810          4409.56               Euro      4409.56             Euro
#
#      payment_format  is_laundering category
# 1345            ACH              1      NaN
# 1346            ACH              1      NaN
# 1347            ACH              1      NaN
# 1348            ACH              1      NaN
# 1349            ACH              1      NaN
# ...             ...            ...      ...
# 1806            ACH              1      NaN
# 1807            ACH              1      NaN
# 1808            ACH              1      NaN
# 1809            ACH              1      NaN
# 1810            ACH              1      NaN
#
# [466 rows x 14 columns]

# %%
stack[stack.from_account=="80F52D550"]
# Out:
#       id   type         timestamp  from_bank from_account  to_bank to_account  \
# 1346   0  STACK  2022/09/03 19:52      40312    80F52D550    23370  80BEA98A0
#
#       amount_received receiving_currency  amount_paid payment_currency  \
# 1346         11975.53           UK Pound     11975.53         UK Pound
#
#      payment_format  is_laundering category
# 1346            ACH              1      NaN

# %% [markdown]
# Stack laundering has a similar problem to bipartite

# %% [markdown]
# # CYCLE
# Cycle is a pattern in which an account starts a transaction and after a specific number of hops, the initial source account become the recipient one

# %%
cycle = ds[ds.type=="CYCLE"]

# %%
cycle[cycle.id==0]
# Out:
#      id   type         timestamp  from_bank from_account  to_bank to_account  \
# 342   0  CYCLE  2022/09/01 00:03       1467    8013C4030       20  80BC62F10
# 343   0  CYCLE  2022/09/01 02:52         20    80BC62F10   240229  80F025640
# 344   0  CYCLE  2022/09/02 08:44     240229    80F025640      217  80FD27570
# 345   0  CYCLE  2022/09/02 12:29        217    80FD27570    24856  8090E8EB0
# 346   0  CYCLE  2022/09/03 10:20      24856    8090E8EB0       71  804ABCE90
# 347   0  CYCLE  2022/09/03 12:08         71    804ABCE90   213737  805494C30
# 348   0  CYCLE  2022/09/03 13:24     213737    805494C30    14290  801B949C0
# 349   0  CYCLE  2022/09/04 03:24      14290    801B949C0    10057  803DE1580
# 350   0  CYCLE  2022/09/04 09:44      10057    803DE1580    28628  80ACEE280
# 351   0  CYCLE  2022/09/04 15:51      28628    80ACEE280     1467  8013C4030
#
#      amount_received receiving_currency  amount_paid   payment_currency  \
# 342         58702.10               Yuan     58702.10               Yuan
# 343          7332.87        Swiss Franc      7332.87        Swiss Franc
# 344         26443.70             Shekel     26443.70             Shekel
# 345         10621.24    Canadian Dollar     10621.24    Canadian Dollar
# 346        637140.60              Rupee    637140.60              Rupee
# 347        621578.18              Rupee    621578.18              Rupee
# 348          7222.58               Euro      7222.58               Euro
# 349        892031.21                Yen    892031.21                Yen
# 350         11364.12  Australian Dollar     11364.12  Australian Dollar
# 351          7945.55          US Dollar      7945.55          US Dollar
#
#     payment_format  is_laundering     category
# 342            ACH              1  Max 10 hops
# 343            ACH              1  Max 10 hops
# 344            ACH              1  Max 10 hops
# 345            ACH              1  Max 10 hops
# 346            ACH              1  Max 10 hops
# 347            ACH              1  Max 10 hops
# 348            ACH              1  Max 10 hops
# 349            ACH              1  Max 10 hops
# 350            ACH              1  Max 10 hops
# 351            ACH              1  Max 10 hops

# %% [markdown]
# That's an example of a 10 hops cycle:
# - the account 8013C4030 starts the transaction
# - after 10 hops it receives money
# - for each transaction the timestamp is younger than the previous one

# %%
cycle[cycle.payment_format!="ACH"]
# Out:
# Empty DataFrame
# Columns: [id, type, timestamp, from_bank, from_account, to_bank, to_account, amount_received, receiving_currency, amount_paid, payment_currency, payment_format, is_laundering, category]
# Index: []

# %%
cycle[cycle.from_account==cycle.to_account]
cycle[cycle.payment_currency!=cycle.receiving_currency]
# Out:
# Empty DataFrame
# Columns: [id, type, timestamp, from_bank, from_account, to_bank, to_account, amount_received, receiving_currency, amount_paid, payment_currency, payment_format, is_laundering, category]
# Index: []

# %%
categories = cycle[['category']].drop_duplicates()
set(categories['category'])
# Out:
# {'Max 10 hops',
#  'Max 11 hops',
#  'Max 12 hops',
#  'Max 2 hops',
#  'Max 3 hops',
#  'Max 4 hops',
#  'Max 5 hops',
#  'Max 6 hops',
#  'Max 7 hops',
#  'Max 8 hops'}

# %%
cycle[cycle.from_account=="811DCA9B0"]
# Out:
#      id   type         timestamp  from_bank from_account  to_bank to_account  \
# 590  47  CYCLE  2022/09/12 17:52        119    811DCA9B0      222  811D80C30
#
#      amount_received receiving_currency  amount_paid payment_currency  \
# 590         19428.85        Saudi Riyal     19428.85      Saudi Riyal
#
#     payment_format  is_laundering    category
# 590            ACH              1  Max 7 hops

# %%
cycle[cycle.category=="Max 10 hops"]
# Out:
#      id   type         timestamp  from_bank from_account  to_bank to_account  \
# 342   0  CYCLE  2022/09/01 00:03       1467    8013C4030       20  80BC62F10
# 343   0  CYCLE  2022/09/01 02:52         20    80BC62F10   240229  80F025640
# 344   0  CYCLE  2022/09/02 08:44     240229    80F025640      217  80FD27570
# 345   0  CYCLE  2022/09/02 12:29        217    80FD27570    24856  8090E8EB0
# 346   0  CYCLE  2022/09/03 10:20      24856    8090E8EB0       71  804ABCE90
# 347   0  CYCLE  2022/09/03 12:08         71    804ABCE90   213737  805494C30
# 348   0  CYCLE  2022/09/03 13:24     213737    805494C30    14290  801B949C0
# 349   0  CYCLE  2022/09/04 03:24      14290    801B949C0    10057  803DE1580
# 350   0  CYCLE  2022/09/04 09:44      10057    803DE1580    28628  80ACEE280
# 351   0  CYCLE  2022/09/04 15:51      28628    80ACEE280     1467  8013C4030
# 352   1  CYCLE  2022/09/01 01:56      13057    80DED0520      211  80A451570
# 353   1  CYCLE  2022/09/01 03:35        211    80A451570    17401  80D179410
# 354   1  CYCLE  2022/09/01 16:58      17401    80D179410    28663  80A976860
# 355   1  CYCLE  2022/09/01 17:21      28663    80A976860      795  80BAEB330
# 356   1  CYCLE  2022/09/02 00:27        795    80BAEB330    17753  806D399E0
# 357   1  CYCLE  2022/09/03 13:44      17753    806D399E0       27  80BE74FC0
# 358   1  CYCLE  2022/09/03 18:35         27    80BE74FC0   239692  80EA93ED0
# 359   1  CYCLE  2022/09/04 01:34     239692    80EA93ED0     1124  8079EC940
# 360   1  CYCLE  2022/09/04 13:55       1124    8079EC940    27103  80F93F560
# 361   1  CYCLE  2022/09/04 18:29      27103    80F93F560    13057  80DED0520
# 362   2  CYCLE  2022/09/01 08:02       5464    802125640     1411  800BFED10
# 363   2  CYCLE  2022/09/01 16:44       1411    800BFED10    12735  80150CB00
# 364   2  CYCLE  2022/09/01 21:54      12735    80150CB00     1674  801309540
# 365   2  CYCLE  2022/09/02 06:52       1674    801309540     1362  800463160
# 366   2  CYCLE  2022/09/03 06:03       1362    800463160     1024  8009FD760
# 367   2  CYCLE  2022/09/03 14:48       1024    8009FD760     3149  8013DB9A0
# 368   2  CYCLE  2022/09/04 12:17       3149    8013DB9A0     1362  8003A56A0
# 369   2  CYCLE  2022/09/04 12:56       1362    8003A56A0    21174  800776AF0
# 370   2  CYCLE  2022/09/04 13:22      21174    800776AF0     1547  8018245C0
# 371   2  CYCLE  2022/09/05 01:27       1547    8018245C0     5464  802125640
# 476  30  CYCLE  2022/09/05 22:55      40064    80EE582B0   120193  80C2E7860
# 477  30  CYCLE  2022/09/06 07:25     120193    80C2E7860     1420  800F5BCB0
# 478  30  CYCLE  2022/09/06 16:00       1420    800F5BCB0    16388  8026F0EF0
# 479  30  CYCLE  2022/09/07 19:26      16388    8026F0EF0    14387  808718090
# 480  30  CYCLE  2022/09/08 02:13      14387    808718090    17222  8033ACE30
# 481  30  CYCLE  2022/09/08 08:30      17222    8033ACE30   112497  80543A870
# 482  30  CYCLE  2022/09/08 10:02     112497    80543A870   116843  8064773A0
# 483  30  CYCLE  2022/09/08 12:52     116843    8064773A0    24032  80C90D1D0
# 484  30  CYCLE  2022/09/09 11:17      24032    80C90D1D0   231744  80BE84A00
# 485  30  CYCLE  2022/09/09 18:03     231744    80BE84A00    40064  80EE582B0
# 574  46  CYCLE  2022/09/09 03:13         23    80016A830      410  80023E0E0
# 575  46  CYCLE  2022/09/09 15:11        410    80023E0E0       11  8000EFAF0
# 576  46  CYCLE  2022/09/11 17:13         11    8000EFAF0       11  80022DF30
# 577  46  CYCLE  2022/09/09 10:48         11    80022DF30       20  80016A6A0
# 578  46  CYCLE  2022/09/09 13:01         20    80016A6A0       23  8002BCFF0
# 579  46  CYCLE  2022/09/10 12:16         23    8002BCFF0       22  800060E60
# 580  46  CYCLE  2022/09/09 12:28         22    800060E60       23  8000FE1F0
# 581  46  CYCLE  2022/09/11 09:24         23    8000FE1F0       12  800063D30
# 582  46  CYCLE  2022/09/10 16:19         12    800063D30       12  80010D740
# 583  46  CYCLE  2022/09/12 00:06         12    80010D740       23  80016A830
# 591  48  CYCLE  2022/09/09 20:17         22    8078DC6E0    17222  8041EDC70
# 592  48  CYCLE  2022/09/09 21:41      17222    8041EDC70    10709  80692A790
# 593  48  CYCLE  2022/09/10 03:01      10709    80692A790    18819  805B9B260
# 594  48  CYCLE  2022/09/10 18:08      18819    805B9B260     1665  8005A25A0
# 595  48  CYCLE  2022/09/11 11:40       1665    8005A25A0    25536  8043410B0
# 596  48  CYCLE  2022/09/11 13:48      25536    8043410B0   113935  807B6EA00
# 597  48  CYCLE  2022/09/11 16:38     113935    807B6EA00    17729  80720B3B0
# 598  48  CYCLE  2022/09/12 13:16      17729    80720B3B0     3149  8032FADC0
# 599  48  CYCLE  2022/09/13 06:06       3149    8032FADC0       20  801A29950
# 600  48  CYCLE  2022/09/13 14:03         20    801A29950       22  8078DC6E0
#
#      amount_received receiving_currency  amount_paid   payment_currency  \
# 342         58702.10               Yuan     58702.10               Yuan
# 343          7332.87        Swiss Franc      7332.87        Swiss Franc
# 344         26443.70             Shekel     26443.70             Shekel
# 345         10621.24    Canadian Dollar     10621.24    Canadian Dollar
# 346        637140.60              Rupee    637140.60              Rupee
# 347        621578.18              Rupee    621578.18              Rupee
# 348          7222.58               Euro      7222.58               Euro
# 349        892031.21                Yen    892031.21                Yen
# 350         11364.12  Australian Dollar     11364.12  Australian Dollar
# 351          7945.55          US Dollar      7945.55          US Dollar
# 352         26390.87  Australian Dollar     26390.87  Australian Dollar
# 353         19934.49          US Dollar     19934.49          US Dollar
# 354         28163.45  Australian Dollar     28163.45  Australian Dollar
# 355         23674.70          US Dollar     23674.70          US Dollar
# 356         23102.65          US Dollar     23102.65          US Dollar
# 357        488461.69       Mexican Peso    488461.69       Mexican Peso
# 358         21138.93        Swiss Franc     21138.93        Swiss Franc
# 359         25434.28          US Dollar     25434.28          US Dollar
# 360         19959.31               Euro     19959.31               Euro
# 361         19959.31               Euro     19959.31               Euro
# 362         16465.55          US Dollar     16465.55          US Dollar
# 363         16465.55          US Dollar     16465.55          US Dollar
# 364         16435.09          US Dollar     16435.09          US Dollar
# 365         16435.09          US Dollar     16435.09          US Dollar
# 366         14025.71               Euro     14025.71               Euro
# 367         16435.09          US Dollar     16435.09          US Dollar
# 368         17142.37          US Dollar     17142.37          US Dollar
# 369         17533.20          US Dollar     17533.20          US Dollar
# 370         14962.84               Euro     14962.84               Euro
# 371         13953.79               Euro     13953.79               Euro
# 476          9468.26               Yuan      9468.26               Yuan
# 477          1408.11          US Dollar      1408.11          US Dollar
# 478          1201.68               Euro      1201.68               Euro
# 479          1553.64          US Dollar      1553.64          US Dollar
# 480          1416.27          US Dollar      1416.27          US Dollar
# 481         94626.05              Rupee     94626.05              Rupee
# 482         99938.50              Ruble     99938.50              Ruble
# 483          1219.41          US Dollar      1219.41          US Dollar
# 484         23554.37       Mexican Peso     23554.37       Mexican Peso
# 485          1065.19          US Dollar      1065.19          US Dollar
# 574         11873.99               Euro     11873.99               Euro
# 575         12614.29               Euro     12614.29               Euro
# 576         12416.77               Euro     12416.77               Euro
# 577         14838.40               Euro     14838.40               Euro
# 578         14053.59               Euro     14053.59               Euro
# 579         14053.59               Euro     14053.59               Euro
# 580         16319.80               Euro     16319.80               Euro
# 581         16324.89               Euro     16324.89               Euro
# 582         15730.69               Euro     15730.69               Euro
# 583         14413.76               Euro     14413.76               Euro
# 591          6058.07          US Dollar      6058.07          US Dollar
# 592          5169.17               Euro      5169.17               Euro
# 593          5840.05          US Dollar      5840.05          US Dollar
# 594          5372.23          US Dollar      5372.23          US Dollar
# 595          4584.66               Euro      4584.66               Euro
# 596          4584.66               Euro      4584.66               Euro
# 597          5372.23          US Dollar      5372.23          US Dollar
# 598          5372.23          US Dollar      5372.23          US Dollar
# 599          4796.72               Euro      4796.72               Euro
# 600          4559.72               Euro      4559.72               Euro
#
#     payment_format  is_laundering     category
# 342            ACH              1  Max 10 hops
# 343            ACH              1  Max 10 hops
# 344            ACH              1  Max 10 hops
# 345            ACH              1  Max 10 hops
# 346            ACH              1  Max 10 hops
# 347            ACH              1  Max 10 hops
# 348            ACH              1  Max 10 hops
# 349            ACH              1  Max 10 hops
# 350            ACH              1  Max 10 hops
# 351            ACH              1  Max 10 hops
# 352            ACH              1  Max 10 hops
# 353            ACH              1  Max 10 hops
# 354            ACH              1  Max 10 hops
# 355            ACH              1  Max 10 hops
# 356            ACH              1  Max 10 hops
# 357            ACH              1  Max 10 hops
# 358            ACH              1  Max 10 hops
# 359            ACH              1  Max 10 hops
# 360            ACH              1  Max 10 hops
# 361            ACH              1  Max 10 hops
# 362            ACH              1  Max 10 hops
# 363            ACH              1  Max 10 hops
# 364            ACH              1  Max 10 hops
# 365            ACH              1  Max 10 hops
# 366            ACH              1  Max 10 hops
# 367            ACH              1  Max 10 hops
# 368            ACH              1  Max 10 hops
# 369            ACH              1  Max 10 hops
# 370            ACH              1  Max 10 hops
# 371            ACH              1  Max 10 hops
# 476            ACH              1  Max 10 hops
# 477            ACH              1  Max 10 hops
# 478            ACH              1  Max 10 hops
# 479            ACH              1  Max 10 hops
# 480            ACH              1  Max 10 hops
# 481            ACH              1  Max 10 hops
# 482            ACH              1  Max 10 hops
# 483            ACH              1  Max 10 hops
# 484            ACH              1  Max 10 hops
# 485            ACH              1  Max 10 hops
# 574            ACH              1  Max 10 hops
# 575            ACH              1  Max 10 hops
# 576            ACH              1  Max 10 hops
# 577            ACH              1  Max 10 hops
# 578            ACH              1  Max 10 hops
# 579            ACH              1  Max 10 hops
# 580            ACH              1  Max 10 hops
# 581            ACH              1  Max 10 hops
# 582            ACH              1  Max 10 hops
# 583            ACH              1  Max 10 hops
# 591            ACH              1  Max 10 hops
# 592            ACH              1  Max 10 hops
# 593            ACH              1  Max 10 hops
# 594            ACH              1  Max 10 hops
# 595            ACH              1  Max 10 hops
# 596            ACH              1  Max 10 hops
# 597            ACH              1  Max 10 hops
# 598            ACH              1  Max 10 hops
# 599            ACH              1  Max 10 hops
# 600            ACH              1  Max 10 hops
